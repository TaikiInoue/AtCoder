# %% [markdown]
# <span class='h2'>D - 金塊ゲーム</span>
# <hr>
# <p>Time Limit: 4 sec / Memory Limit: 512 MB</p>
#
# <div id='task-statement'>
# <div id='task-statement'>
# <div class='part'>
#
# <section>
# <h3>問題文</h3>
#
# <p>高橋君はとあるゲームをプレイしている。このゲームでは縦横方向に無限に広がるマス目の上で行われる。各マス目は正方形状で、各辺は東西方向または南北方向に平行である。マス目のうちあるマスには (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mn' id='MJXp-Span-2'>0</span></span></span><script type='math/tex' id='MathJax-Element-1'>0</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-3'><span class='MJXp-mn' id='MJXp-Span-4'>0</span></span></span><script type='math/tex' id='MathJax-Element-2'>0</script></var>) という数字の組が割り当てられており、このマスから東方向に <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-6'>x</span></span></span><script type='math/tex' id='MathJax-Element-3'>x</script></var> マス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-7'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-8'>x</span><span class='MJXp-mo' id='MJXp-Span-9' style='margin-left: 0.333em; margin-right: 0.333em;'>&lt;</span><span class='MJXp-mn' id='MJXp-Span-10'>0</span></span></span><script type='math/tex' id='MathJax-Element-4'>x<0</script></var> のときは西方向に <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-11'><span class='MJXp-mo' id='MJXp-Span-12' style='margin-left: 0em; margin-right: 0.111em;'>−</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-13'>x</span></span></span><script type='math/tex' id='MathJax-Element-5'>-x</script></var> マス)進み、北方向に <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-14'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-15'>y</span></span></span><script type='math/tex' id='MathJax-Element-6'>y</script></var> マス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-16'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-17'>y</span><span class='MJXp-mo' id='MJXp-Span-18' style='margin-left: 0.333em; margin-right: 0.333em;'>&lt;</span><span class='MJXp-mn' id='MJXp-Span-19'>0</span></span></span><script type='math/tex' id='MathJax-Element-7'>y<0</script></var> のときは南方向に <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-20'><span class='MJXp-mo' id='MJXp-Span-21' style='margin-left: 0em; margin-right: 0.111em;'>−</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-22'>y</span></span></span><script type='math/tex' id='MathJax-Element-8'>-y</script></var> マス)進んだところにあるマスには (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-23'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-24'>x</span></span></span><script type='math/tex' id='MathJax-Element-9'>x</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-25'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-26'>y</span></span></span><script type='math/tex' id='MathJax-Element-10'>y</script></var>) という数字の組が割り当てられている。</p>
#
# <p>マス目上には <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-27'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-28'>W</span></span></span><script type='math/tex' id='MathJax-Element-11'>W</script></var> × <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-29'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-30'>H</span></span></span><script type='math/tex' id='MathJax-Element-12'>H</script></var> 個の金塊がある。これらの金塊は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-31'><span class='MJXp-mn' id='MJXp-Span-32'>1</span></span></span><script type='math/tex' id='MathJax-Element-13'>1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-33'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-34'>p</span></span></span><script type='math/tex' id='MathJax-Element-14'>p</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-35'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-36'>W</span></span></span><script type='math/tex' id='MathJax-Element-15'>W</script></var> かつ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-37'><span class='MJXp-mn' id='MJXp-Span-38'>1</span></span></span><script type='math/tex' id='MathJax-Element-16'>1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-39'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-40'>q</span></span></span><script type='math/tex' id='MathJax-Element-17'>q</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-41'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-42'>H</span></span></span><script type='math/tex' id='MathJax-Element-18'>H</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-43'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-44'>p</span></span></span><script type='math/tex' id='MathJax-Element-19'>p</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-45'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-46'>q</span></span></span><script type='math/tex' id='MathJax-Element-20'>q</script></var>) に <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-47'><span class='MJXp-mn' id='MJXp-Span-48'>1</span></span></span><script type='math/tex' id='MathJax-Element-21'>1</script></var> 個ずつ置かれている。また、金塊があるマスのうちちょうど <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-49'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-50'>N</span></span></span><script type='math/tex' id='MathJax-Element-22'>N</script></var> マスには金塊回収装置がある。装置には <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-51'><span class='MJXp-mn' id='MJXp-Span-52'>1</span></span></span><script type='math/tex' id='MathJax-Element-23'>1</script></var> から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-53'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-54'>N</span></span></span><script type='math/tex' id='MathJax-Element-24'>N</script></var> までの番号が付いている。どの <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-55'><span class='MJXp-mn' id='MJXp-Span-56'>2</span></span></span><script type='math/tex' id='MathJax-Element-25'>2</script></var> つのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-57'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-58'>a</span></span></span><script type='math/tex' id='MathJax-Element-26'>a</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-59'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-60'>b</span></span></span><script type='math/tex' id='MathJax-Element-27'>b</script></var>) , (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-61'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-62'>c</span></span></span><script type='math/tex' id='MathJax-Element-28'>c</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-63'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-64'>d</span></span></span><script type='math/tex' id='MathJax-Element-29'>d</script></var>) に関しても、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-65'><span class='MJXp-mn' id='MJXp-Span-66'>2</span></span></span><script type='math/tex' id='MathJax-Element-30'>2</script></var> つのマスの両方に装置があるならば、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-67'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-68'>a</span><span class='MJXp-mo' id='MJXp-Span-69' style='margin-left: 0.333em; margin-right: 0.333em;'>≠</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-70'>c</span></span></span><script type='math/tex' id='MathJax-Element-31'>a≠c</script></var> かつ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-71'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-72'>b</span><span class='MJXp-mo' id='MJXp-Span-73' style='margin-left: 0.333em; margin-right: 0.333em;'>≠</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-74'>d</span></span></span><script type='math/tex' id='MathJax-Element-32'>b≠d</script></var> である。また、複数の装置が同じマスにあることはない。最初、どの金塊回収装置も作動していない。</p>
#
# <p>金塊回収装置は作動すると、まずは装置のあるマスにある金塊を回収する。その後、東西南北それぞれの方向にクレーンを伸ばすことで更に金塊を回収することができる。クレーンの性質上、クレーンを下ろす場所には金塊がなく、かつ回収する区間では金塊が連続して存在していなければならない。つまり、クレーンのあるマスを (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-75'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-76'>x</span></span></span><script type='math/tex' id='MathJax-Element-33'>x</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-77'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-78'>y</span></span></span><script type='math/tex' id='MathJax-Element-34'>y</script></var>) としたとき、以下に示す条件でのみクレーンを下ろし、金塊を回収することができる。</p>
#
# <ul>
#
# <li>
# <p class='first'>東方向に回収する処理：次の条件を満たす整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-79'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-80'>p</span></span></span><script type='math/tex' id='MathJax-Element-35'>p</script></var> を選ぶ。その後、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-81'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-82'>x</span><span class='MJXp-mo' id='MJXp-Span-83' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-84'>1</span></span></span><script type='math/tex' id='MathJax-Element-36'>x+1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-85'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-86'>i</span></span></span><script type='math/tex' id='MathJax-Element-37'>i</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-87'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-88'>p</span><span class='MJXp-mo' id='MJXp-Span-89' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-90'>1</span></span></span><script type='math/tex' id='MathJax-Element-38'>p-1</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-91'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-92'>i</span></span></span><script type='math/tex' id='MathJax-Element-39'>i</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-93'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-94'>y</span></span></span><script type='math/tex' id='MathJax-Element-40'>y</script></var>) の金塊を回収する。</p>
#
# <blockquote>
#
# <ul class='simple'>
#
# <li>条件：<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-95'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-96'>p</span></span></span><script type='math/tex' id='MathJax-Element-41'>p</script></var> &gt; <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-97'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-98'>x</span><span class='MJXp-mo' id='MJXp-Span-99' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-100'>1</span></span></span><script type='math/tex' id='MathJax-Element-42'>x+1</script></var> であり、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-101'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-102'>x</span><span class='MJXp-mo' id='MJXp-Span-103' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-104'>1</span></span></span><script type='math/tex' id='MathJax-Element-43'>x+1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-105'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-106'>i</span></span></span><script type='math/tex' id='MathJax-Element-44'>i</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-107'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-108'>p</span><span class='MJXp-mo' id='MJXp-Span-109' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-110'>1</span></span></span><script type='math/tex' id='MathJax-Element-45'>p-1</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-111'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-112'>i</span></span></span><script type='math/tex' id='MathJax-Element-46'>i</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-113'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-114'>y</span></span></span><script type='math/tex' id='MathJax-Element-47'>y</script></var>) に金塊があり、かつマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-115'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-116'>p</span></span></span><script type='math/tex' id='MathJax-Element-48'>p</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-117'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-118'>y</span></span></span><script type='math/tex' id='MathJax-Element-49'>y</script></var>) に金塊がない。</li>
#
# </ul>
#
# </blockquote>
#
# </li>
#
# <li>
# <p class='first'>西方向に回収する処理：次の条件を満たす整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-119'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-120'>p</span></span></span><script type='math/tex' id='MathJax-Element-50'>p</script></var> を選ぶ。その後、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-121'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-122'>p</span><span class='MJXp-mo' id='MJXp-Span-123' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-124'>1</span></span></span><script type='math/tex' id='MathJax-Element-51'>p+1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-125'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-126'>i</span></span></span><script type='math/tex' id='MathJax-Element-52'>i</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-127'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-128'>x</span><span class='MJXp-mo' id='MJXp-Span-129' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-130'>1</span></span></span><script type='math/tex' id='MathJax-Element-53'>x-1</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-131'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-132'>i</span></span></span><script type='math/tex' id='MathJax-Element-54'>i</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-133'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-134'>y</span></span></span><script type='math/tex' id='MathJax-Element-55'>y</script></var>) の金塊を回収する。</p>
#
# <blockquote>
#
# <ul class='simple'>
#
# <li>条件：<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-135'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-136'>p</span></span></span><script type='math/tex' id='MathJax-Element-56'>p</script></var> &lt; <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-137'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-138'>x</span><span class='MJXp-mo' id='MJXp-Span-139' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-140'>1</span></span></span><script type='math/tex' id='MathJax-Element-57'>x-1</script></var> であり、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-141'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-142'>p</span><span class='MJXp-mo' id='MJXp-Span-143' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-144'>1</span></span></span><script type='math/tex' id='MathJax-Element-58'>p+1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-145'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-146'>i</span></span></span><script type='math/tex' id='MathJax-Element-59'>i</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-147'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-148'>x</span><span class='MJXp-mo' id='MJXp-Span-149' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-150'>1</span></span></span><script type='math/tex' id='MathJax-Element-60'>x-1</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-151'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-152'>i</span></span></span><script type='math/tex' id='MathJax-Element-61'>i</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-153'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-154'>y</span></span></span><script type='math/tex' id='MathJax-Element-62'>y</script></var>) に金塊があり、かつマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-155'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-156'>p</span></span></span><script type='math/tex' id='MathJax-Element-63'>p</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-157'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-158'>y</span></span></span><script type='math/tex' id='MathJax-Element-64'>y</script></var>) に金塊がない。</li>
#
# </ul>
#
# </blockquote>
#
# </li>
#
# <li>
# <p class='first'>南方向に回収する処理：次の条件を満たす整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-159'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-160'>q</span></span></span><script type='math/tex' id='MathJax-Element-65'>q</script></var> を選ぶ。その後、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-161'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-162'>q</span><span class='MJXp-mo' id='MJXp-Span-163' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-164'>1</span></span></span><script type='math/tex' id='MathJax-Element-66'>q+1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-165'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-166'>j</span></span></span><script type='math/tex' id='MathJax-Element-67'>j</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-167'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-168'>y</span><span class='MJXp-mo' id='MJXp-Span-169' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-170'>1</span></span></span><script type='math/tex' id='MathJax-Element-68'>y-1</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-171'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-172'>x</span></span></span><script type='math/tex' id='MathJax-Element-69'>x</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-173'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-174'>j</span></span></span><script type='math/tex' id='MathJax-Element-70'>j</script></var>) の金塊を回収する。</p>
#
# <blockquote>
#
# <ul class='simple'>
#
# <li>条件：<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-175'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-176'>q</span></span></span><script type='math/tex' id='MathJax-Element-71'>q</script></var> &lt; <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-177'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-178'>y</span><span class='MJXp-mo' id='MJXp-Span-179' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-180'>1</span></span></span><script type='math/tex' id='MathJax-Element-72'>y-1</script></var> であり、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-181'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-182'>q</span><span class='MJXp-mo' id='MJXp-Span-183' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-184'>1</span></span></span><script type='math/tex' id='MathJax-Element-73'>q+1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-185'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-186'>j</span></span></span><script type='math/tex' id='MathJax-Element-74'>j</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-187'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-188'>y</span><span class='MJXp-mo' id='MJXp-Span-189' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-190'>1</span></span></span><script type='math/tex' id='MathJax-Element-75'>y-1</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-191'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-192'>x</span></span></span><script type='math/tex' id='MathJax-Element-76'>x</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-193'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-194'>j</span></span></span><script type='math/tex' id='MathJax-Element-77'>j</script></var>) に金塊があり、かつマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-195'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-196'>x</span></span></span><script type='math/tex' id='MathJax-Element-78'>x</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-197'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-198'>q</span></span></span><script type='math/tex' id='MathJax-Element-79'>q</script></var>) に金塊がない。</li>
#
# </ul>
#
# </blockquote>
#
# </li>
#
# <li>
# <p class='first'>北方向に回収する処理：次の条件を満たす整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-199'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-200'>q</span></span></span><script type='math/tex' id='MathJax-Element-80'>q</script></var> を選ぶ。その後、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-201'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-202'>y</span><span class='MJXp-mo' id='MJXp-Span-203' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-204'>1</span></span></span><script type='math/tex' id='MathJax-Element-81'>y+1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-205'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-206'>j</span></span></span><script type='math/tex' id='MathJax-Element-82'>j</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-207'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-208'>q</span><span class='MJXp-mo' id='MJXp-Span-209' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-210'>1</span></span></span><script type='math/tex' id='MathJax-Element-83'>q-1</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-211'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-212'>x</span></span></span><script type='math/tex' id='MathJax-Element-84'>x</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-213'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-214'>j</span></span></span><script type='math/tex' id='MathJax-Element-85'>j</script></var>) の金塊を回収する。</p>
#
# <blockquote>
#
# <ul class='simple'>
#
# <li>条件：<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-215'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-216'>q</span></span></span><script type='math/tex' id='MathJax-Element-86'>q</script></var> &gt; <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-217'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-218'>y</span><span class='MJXp-mo' id='MJXp-Span-219' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-220'>1</span></span></span><script type='math/tex' id='MathJax-Element-87'>y+1</script></var> であり、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-221'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-222'>y</span><span class='MJXp-mo' id='MJXp-Span-223' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-224'>1</span></span></span><script type='math/tex' id='MathJax-Element-88'>y+1</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-225'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-226'>j</span></span></span><script type='math/tex' id='MathJax-Element-89'>j</script></var> ≦ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-227'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-228'>q</span><span class='MJXp-mo' id='MJXp-Span-229' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-230'>1</span></span></span><script type='math/tex' id='MathJax-Element-90'>q-1</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-231'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-232'>x</span></span></span><script type='math/tex' id='MathJax-Element-91'>x</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-233'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-234'>j</span></span></span><script type='math/tex' id='MathJax-Element-92'>j</script></var>) に金塊があり、かつマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-235'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-236'>x</span></span></span><script type='math/tex' id='MathJax-Element-93'>x</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-237'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-238'>q</span></span></span><script type='math/tex' id='MathJax-Element-94'>q</script></var>) に金塊がない。</li>
#
# </ul>
#
# </blockquote>
#
# </li>
#
# </ul>
#
# <p>それぞれの方向に関して、条件を満たす <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-239'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-240'>p</span></span></span><script type='math/tex' id='MathJax-Element-95'>p</script></var> または <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-241'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-242'>q</span></span></span><script type='math/tex' id='MathJax-Element-96'>q</script></var> が存在しない場合は、その方向にクレーンを伸ばすことができない。</p>
#
# <p>また、それぞれの方向に関して、金塊を回収可能ならば、必ず回収しなければならない。下に条件を満たす回収方法の一例を示す。ただし、以降の図において装置を <code>M</code> の記号で表し、回収可能な範囲は太枠で表している。</p>
#
# <center><img src='http://abc008.contest.atcoder.jp/img/abc/008/4-1.png' width='272px' height='208px'></center><p></p>
#
# <p>高橋君はすべての装置を順番を決めて作動させるつもりである。作動の順番によっては、最終的に得られる金塊の個数が変化するかもしれない。金塊が大好きな高橋君は、最終的に得られる金塊の個数をできるだけ多くしようと考えている。</p>
#
# <p>あなたは高橋くんの代わりに、最大値を計算するプログラムを作成してほしい。</p>
#
# </section>
# </div>
# <hr>
# <div class='io-style'>
# <div class='part'>
#
# <section>
# <h3>入力</h3>
#
# <p>入力は以下の形式で標準入力から与えられる。</p>
#
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-243'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-244'>W</span></span></span><script type='math/tex' id='MathJax-Element-97'>W</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-245'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-246'>H</span></span></span><script type='math/tex' id='MathJax-Element-98'>H</script></var>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-247'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-248'>N</span></span></span><script type='math/tex' id='MathJax-Element-99'>N</script></var>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-249'><span class='MJXp-msubsup' id='MJXp-Span-250'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-251' style='margin-right: 0.05em;'>X</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-252' style='vertical-align: -0.4em;'>1</span></span></span></span><script type='math/tex' id='MathJax-Element-100'>X_1</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-253'><span class='MJXp-msubsup' id='MJXp-Span-254'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-255' style='margin-right: 0.05em;'>Y</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-256' style='vertical-align: -0.4em;'>1</span></span></span></span><script type='math/tex' id='MathJax-Element-101'>Y_1</script></var>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-257'><span class='MJXp-msubsup' id='MJXp-Span-258'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-259' style='margin-right: 0.05em;'>X</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-260' style='vertical-align: -0.4em;'>2</span></span></span></span><script type='math/tex' id='MathJax-Element-102'>X_2</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-261'><span class='MJXp-msubsup' id='MJXp-Span-262'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-263' style='margin-right: 0.05em;'>Y</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-264' style='vertical-align: -0.4em;'>2</span></span></span></span><script type='math/tex' id='MathJax-Element-103'>Y_2</script></var>
# :
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-265'><span class='MJXp-msubsup' id='MJXp-Span-266'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-267' style='margin-right: 0.05em;'>X</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-268' style='vertical-align: -0.4em;'>N</span></span></span></span><script type='math/tex' id='MathJax-Element-104'>X_N</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-269'><span class='MJXp-msubsup' id='MJXp-Span-270'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-271' style='margin-right: 0.05em;'>Y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-272' style='vertical-align: -0.4em;'>N</span></span></span></span><script type='math/tex' id='MathJax-Element-105'>Y_N</script></var>
# </pre>
#
# <ul class='simple'>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-273'><span class='MJXp-mn' id='MJXp-Span-274'>1</span></span></span><script type='math/tex' id='MathJax-Element-106'>1</script></var> 行目には、金塊の個数と配置に関する <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-275'><span class='MJXp-mn' id='MJXp-Span-276'>2</span></span></span><script type='math/tex' id='MathJax-Element-107'>2</script></var> つの整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-277'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-278'>W</span><span class='MJXp-mo' id='MJXp-Span-279' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-280'>1</span><span class='MJXp-mo' id='MJXp-Span-281' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-282'>W</span><span class='MJXp-mo' id='MJXp-Span-283' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-msubsup' id='MJXp-Span-284'><span class='MJXp-mn' id='MJXp-Span-285' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-286' style='vertical-align: 0.5em;'>6</span></span><span class='MJXp-mo' id='MJXp-Span-287' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-108'>W (1 ≦ W ≦ 10^6)</script></var> と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-288'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-289'>H</span><span class='MJXp-mo' id='MJXp-Span-290' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-291'>1</span><span class='MJXp-mo' id='MJXp-Span-292' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-293'>H</span><span class='MJXp-mo' id='MJXp-Span-294' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-msubsup' id='MJXp-Span-295'><span class='MJXp-mn' id='MJXp-Span-296' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-297' style='vertical-align: 0.5em;'>6</span></span><span class='MJXp-mo' id='MJXp-Span-298' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-109'>H (1 ≦ H ≦ 10^6)</script></var> が空白区切りで与えられる。</li>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-299'><span class='MJXp-mn' id='MJXp-Span-300'>2</span></span></span><script type='math/tex' id='MathJax-Element-110'>2</script></var> 行目には、金塊回収装置の個数を表す整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-301'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-302'>N</span><span class='MJXp-mo' id='MJXp-Span-303' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-304'>1</span><span class='MJXp-mo' id='MJXp-Span-305' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-306'>N</span><span class='MJXp-mo' id='MJXp-Span-307' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-308'>30</span><span class='MJXp-mo' id='MJXp-Span-309' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-111'>N (1 ≦ N ≦ 30)</script></var> が与えられる。</li>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-310'><span class='MJXp-mn' id='MJXp-Span-311'>3</span></span></span><script type='math/tex' id='MathJax-Element-112'>3</script></var> 行目から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-312'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-313'>N</span></span></span><script type='math/tex' id='MathJax-Element-113'>N</script></var> 行のうち <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-314'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-315'>i</span><span class='MJXp-mo' id='MJXp-Span-316' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-317'>1</span><span class='MJXp-mo' id='MJXp-Span-318' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-319'>i</span><span class='MJXp-mo' id='MJXp-Span-320' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-321'>N</span><span class='MJXp-mo' id='MJXp-Span-322' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-114'>i (1 ≦ i ≦ N)</script></var> 行目には、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-323'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-324'>i</span></span></span><script type='math/tex' id='MathJax-Element-115'>i</script></var> 番目の装置があるマスに関する <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-325'><span class='MJXp-mn' id='MJXp-Span-326'>2</span></span></span><script type='math/tex' id='MathJax-Element-116'>2</script></var> つの整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-327'><span class='MJXp-msubsup' id='MJXp-Span-328'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-329' style='margin-right: 0.05em;'>X</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-330' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-331' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-332'>1</span><span class='MJXp-mo' id='MJXp-Span-333' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-msubsup' id='MJXp-Span-334'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-335' style='margin-right: 0.05em;'>X</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-336' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-337' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-338'>W</span><span class='MJXp-mo' id='MJXp-Span-339' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-117'>X_i (1 ≦ X_i ≦ W)</script></var> と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-340'><span class='MJXp-msubsup' id='MJXp-Span-341'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-342' style='margin-right: 0.05em;'>Y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-343' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-344' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-345'>1</span><span class='MJXp-mo' id='MJXp-Span-346' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-msubsup' id='MJXp-Span-347'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-348' style='margin-right: 0.05em;'>Y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-349' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-350' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-351'>H</span><span class='MJXp-mo' id='MJXp-Span-352' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-118'>Y_i (1 ≦ Y_i ≦ H)</script></var> が空白区切りで与えられる。これは、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-353'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-354'>i</span></span></span><script type='math/tex' id='MathJax-Element-119'>i</script></var> 番目の装置がマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-355'><span class='MJXp-msubsup' id='MJXp-Span-356'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-357' style='margin-right: 0.05em;'>X</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-358' style='vertical-align: -0.4em;'>i</span></span></span></span><script type='math/tex' id='MathJax-Element-120'>X_i</script></var> , <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-359'><span class='MJXp-msubsup' id='MJXp-Span-360'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-361' style='margin-right: 0.05em;'>Y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-362' style='vertical-align: -0.4em;'>i</span></span></span></span><script type='math/tex' id='MathJax-Element-121'>Y_i</script></var>) にあることを表す。</li>
#
# </ul>
#
# <p>また、この入力では、さらに以下の条件も満たされる。</p>
#
# <ul class='simple'>
#
# <li>任意の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-363'><span class='MJXp-mn' id='MJXp-Span-364'>2</span></span></span><script type='math/tex' id='MathJax-Element-122'>2</script></var> つの整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-365'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-366'>i</span><span class='MJXp-mo' id='MJXp-Span-367' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-368'>j</span><span class='MJXp-mo' id='MJXp-Span-369' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-370'>1</span><span class='MJXp-mo' id='MJXp-Span-371' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-372'>i</span><span class='MJXp-mo' id='MJXp-Span-373' style='margin-left: 0.333em; margin-right: 0.333em;'>&lt;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-374'>j</span><span class='MJXp-mo' id='MJXp-Span-375' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-376'>N</span><span class='MJXp-mo' id='MJXp-Span-377' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-123'>i,j (1 ≦ i < j ≦ N)</script></var> について、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-378'><span class='MJXp-msubsup' id='MJXp-Span-379'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-380' style='margin-right: 0.05em;'>X</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-381' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-382' style='margin-left: 0.333em; margin-right: 0.333em;'>≠</span><span class='MJXp-msubsup' id='MJXp-Span-383'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-384' style='margin-right: 0.05em;'>X</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-385' style='vertical-align: -0.4em;'>j</span></span></span></span><script type='math/tex' id='MathJax-Element-124'>X_i ≠ X_j</script></var> かつ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-386'><span class='MJXp-msubsup' id='MJXp-Span-387'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-388' style='margin-right: 0.05em;'>Y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-389' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-390' style='margin-left: 0.333em; margin-right: 0.333em;'>≠</span><span class='MJXp-msubsup' id='MJXp-Span-391'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-392' style='margin-right: 0.05em;'>Y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-393' style='vertical-align: -0.4em;'>j</span></span></span></span><script type='math/tex' id='MathJax-Element-125'>Y_i ≠ Y_j</script></var> である。</li>
#
# </ul>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>部分点</h3>
#
# <p>この問題には部分点が設定されている。</p>
#
# <ul class='simple'>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-394'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-395'>N</span><span class='MJXp-mo' id='MJXp-Span-396' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-397'>8</span></span></span><script type='math/tex' id='MathJax-Element-126'>N ≦ 8</script></var> , <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-398'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-399'>W</span><span class='MJXp-mo' id='MJXp-Span-400' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-401'>80</span></span></span><script type='math/tex' id='MathJax-Element-127'>W ≦ 80</script></var> , <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-402'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-403'>H</span><span class='MJXp-mo' id='MJXp-Span-404' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-405'>80</span></span></span><script type='math/tex' id='MathJax-Element-128'>H ≦ 80</script></var> を満たすデータセット <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-406'><span class='MJXp-mn' id='MJXp-Span-407'>1</span></span></span><script type='math/tex' id='MathJax-Element-129'>1</script></var> に正解した場合は、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-408'><span class='MJXp-mn' id='MJXp-Span-409'>80</span></span></span><script type='math/tex' id='MathJax-Element-130'>80</script></var> 点が与えられる。</li>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-410'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-411'>W</span><span class='MJXp-mo' id='MJXp-Span-412' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-413'>80</span></span></span><script type='math/tex' id='MathJax-Element-131'>W ≦ 80</script></var> , <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-414'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-415'>H</span><span class='MJXp-mo' id='MJXp-Span-416' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-417'>80</span></span></span><script type='math/tex' id='MathJax-Element-132'>H ≦ 80</script></var> を満たすデータセット <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-418'><span class='MJXp-mn' id='MJXp-Span-419'>2</span></span></span><script type='math/tex' id='MathJax-Element-133'>2</script></var> に正解した場合は、さらに <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-420'><span class='MJXp-mn' id='MJXp-Span-421'>19</span></span></span><script type='math/tex' id='MathJax-Element-134'>19</script></var> 点が与えられ、合計で <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-422'><span class='MJXp-mn' id='MJXp-Span-423'>99</span></span></span><script type='math/tex' id='MathJax-Element-135'>99</script></var> 点が得られる。</li>
#
# <li>追加制約のないデータセット <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-424'><span class='MJXp-mn' id='MJXp-Span-425'>3</span></span></span><script type='math/tex' id='MathJax-Element-136'>3</script></var> に正解した場合は、さらに <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-426'><span class='MJXp-mn' id='MJXp-Span-427'>1</span></span></span><script type='math/tex' id='MathJax-Element-137'>1</script></var> 点が与えられ、合計で <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-428'><span class='MJXp-mn' id='MJXp-Span-429'>100</span></span></span><script type='math/tex' id='MathJax-Element-138'>100</script></var> 点が得られる。</li>
#
# </ul>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力</h3>
#
# <p>回収可能な金塊の個数の最大値を出力せよ。出力の末尾にも改行を入れること。</p>
#
# </section>
# </div>
# </div>
# <hr>
# <div class='part'>
#
# <section>
# <h3>入力例1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample0'>6 4
# 3
# 2 4
# 3 1
# 4 3
# </pre>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力例1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample1'>19
# </pre>
#
# <p>入力例 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-430'><span class='MJXp-mn' id='MJXp-Span-431'>1</span></span></span><script type='math/tex' id='MathJax-Element-139'>1</script></var> において、初期状態は以下のようになっています。</p>
#
# <center><img src='http://abc008.contest.atcoder.jp/img/abc/008/4-2.png' width='272px' height='208px'></center><p></p>
#
# <p>以下に示すように、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-432'><span class='MJXp-mn' id='MJXp-Span-433'>1</span></span></span><script type='math/tex' id='MathJax-Element-140'>1</script></var> 番目、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-434'><span class='MJXp-mn' id='MJXp-Span-435'>2</span></span></span><script type='math/tex' id='MathJax-Element-141'>2</script></var> 番目、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-436'><span class='MJXp-mn' id='MJXp-Span-437'>3</span></span></span><script type='math/tex' id='MathJax-Element-142'>3</script></var> 番目の装置という順番で実行することにより、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-438'><span class='MJXp-mn' id='MJXp-Span-439'>19</span></span></span><script type='math/tex' id='MathJax-Element-143'>19</script></var> 個の金塊を回収できます。</p>
#
# <center><img src='http://abc008.contest.atcoder.jp/img/abc/008/4-3.png' width='560px' height='432px'></center><p></p>
#
# </section>
# </div>
# <hr>
# <div class='part'>
#
# <section>
# <h3>入力例2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample2'>3 3
# 3
# 1 1
# 2 3
# 3 2
# </pre>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力例2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample3'>9
# </pre>
#
# <p>うまく稼働させればすべての金塊を回収することができます。</p>
#
# </section>
# </div>
# <hr>
# <div class='part'>
#
# <section>
# <h3>入力例3 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample4' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample4' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample4'>15 10
# 8
# 7 10
# 12 8
# 4 4
# 5 7
# 9 9
# 1 6
# 6 5
# 3 2
# </pre>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力例3 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample5' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample5' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample5'>112
# </pre>
#
# </section>
# </div>
# </div>
#
# </div>
#
#
#
#
# </div>
# </div>
#
#
#
# <hr>
