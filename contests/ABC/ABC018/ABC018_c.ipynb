# %% [markdown]
# <span class='h2'>C - 菱型カウント</span>
# <hr>
# <p>Time Limit: 2 sec / Memory Limit: 256 MB</p>
#
# <div id='task-statement'>
# <div id='task-statement'>
# <div class='part'>
#
# <section>
# <h3>問題文</h3>
#
# <p>縦 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-2'>R</span></span></span><script type='math/tex' id='MathJax-Element-1'>R</script></var> 行、横 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-3'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-4'>C</span></span></span><script type='math/tex' id='MathJax-Element-2'>C</script></var> 列の長方形領域がある。上から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-6'>i</span><span class='MJXp-mo' id='MJXp-Span-7' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-8'>1</span><span class='MJXp-mo' id='MJXp-Span-9' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-10'>i</span><span class='MJXp-mo' id='MJXp-Span-11' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-12'>R</span><span class='MJXp-mo' id='MJXp-Span-13' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-3'>i (1 ≦ i ≦ R)</script></var> 行目、左から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-14'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-15'>j</span><span class='MJXp-mo' id='MJXp-Span-16' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-17'>1</span><span class='MJXp-mo' id='MJXp-Span-18' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-19'>j</span><span class='MJXp-mo' id='MJXp-Span-20' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-21'>C</span><span class='MJXp-mo' id='MJXp-Span-22' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-4'>j (1 ≦ j ≦ C)</script></var> 列目にあるマスをマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-23'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-24'>i</span></span></span><script type='math/tex' id='MathJax-Element-5'>i</script></var>, <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-25'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-26'>j</span></span></span><script type='math/tex' id='MathJax-Element-6'>j</script></var>) と呼ぶことにする。これらのマスのうちいくつかのマスは黒く、他のマスは白く塗られている。</p>
#
# <p>また、ある整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-27'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-28'>K</span></span></span><script type='math/tex' id='MathJax-Element-7'>K</script></var> が定められている。</p>
#
# <p>ここで、以下の条件を満たすように新たに緑色を塗ることを考える。<font color='red'>この操作は1 回だけ行う。</font></p>
#
# <ul class='simple'>
#
# <li>ある整数 の組 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-29'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-30'>x</span><span class='MJXp-mo' id='MJXp-Span-31' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-32'>K</span><span class='MJXp-mo' id='MJXp-Span-33' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-34'>x</span><span class='MJXp-mo' id='MJXp-Span-35' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-36'>R</span><span class='MJXp-mo' id='MJXp-Span-37' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-38'>K</span><span class='MJXp-mo' id='MJXp-Span-39' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-40'>1</span><span class='MJXp-mo' id='MJXp-Span-41' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-8'>x (K ≦ x ≦ R - K + 1)</script></var>, <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-42'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-43'>y</span><span class='MJXp-mo' id='MJXp-Span-44' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-45'>K</span><span class='MJXp-mo' id='MJXp-Span-46' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-47'>y</span><span class='MJXp-mo' id='MJXp-Span-48' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-49'>C</span><span class='MJXp-mo' id='MJXp-Span-50' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-51'>K</span><span class='MJXp-mo' id='MJXp-Span-52' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-53'>1</span><span class='MJXp-mo' id='MJXp-Span-54' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-9'>y (K ≦ y ≦ C - K + 1)</script></var> に対して、|<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-55'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-56'>i</span><span class='MJXp-mo' id='MJXp-Span-57' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-58'>x</span></span></span><script type='math/tex' id='MathJax-Element-10'>i-x</script></var>|+|<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-59'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-60'>j</span><span class='MJXp-mo' id='MJXp-Span-61' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-62'>y</span></span></span><script type='math/tex' id='MathJax-Element-11'>j-y</script></var>|<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-63'><span class='MJXp-mo' id='MJXp-Span-64' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-65'>K</span><span class='MJXp-mo' id='MJXp-Span-66' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-67'>1</span></span></span><script type='math/tex' id='MathJax-Element-12'>≦ K - 1</script></var> を満たすすべてのマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-68'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-69'>i</span></span></span><script type='math/tex' id='MathJax-Element-13'>i</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-70'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-71'>j</span></span></span><script type='math/tex' id='MathJax-Element-14'>j</script></var>) について、マス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-72'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-73'>i</span></span></span><script type='math/tex' id='MathJax-Element-15'>i</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-74'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-75'>j</span></span></span><script type='math/tex' id='MathJax-Element-16'>j</script></var>) は元々白いマスで、かつ、この操作で緑色に塗られる。<font color='red'>さらに、|<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-76'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-77'>i</span><span class='MJXp-mo' id='MJXp-Span-78' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-79'>x</span></span></span><script type='math/tex' id='MathJax-Element-17'>i-x</script></var>|+|<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-80'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-81'>j</span><span class='MJXp-mo' id='MJXp-Span-82' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-83'>y</span></span></span><script type='math/tex' id='MathJax-Element-18'>j-y</script></var>|<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-84'><span class='MJXp-mo' id='MJXp-Span-85' style='margin-left: 0.333em; margin-right: 0.333em;'>≧</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-86'>K</span></span></span><script type='math/tex' id='MathJax-Element-19'>≧ K</script></var> を満たすすべてのマスについて、そのマスは緑色に塗らない。</font></li>
#
# </ul>
#
# <p>このような色の塗り方の総数はいくらか。ただし、ここでいう塗り方とは、どのマスがどの色になったかという組み合わせのことで、色の塗る順番は考慮しないものとする。</p>
#
# </section>
# </div>
# <hr>
# <div class='io-style'>
# <div class='part'>
#
# <section>
# <h3>入力</h3>
#
# <p>入力は以下の形式で標準入力から与えられる。</p>
#
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-87'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-88'>R</span></span></span><script type='math/tex' id='MathJax-Element-20'>R</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-89'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-90'>C</span></span></span><script type='math/tex' id='MathJax-Element-21'>C</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-91'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-92'>K</span></span></span><script type='math/tex' id='MathJax-Element-22'>K</script></var>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-93'><span class='MJXp-msubsup' id='MJXp-Span-94'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-95' style='margin-right: 0.05em;'>s</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-96' style='vertical-align: -0.4em;'>1</span></span></span></span><script type='math/tex' id='MathJax-Element-23'>s_1</script></var>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-97'><span class='MJXp-msubsup' id='MJXp-Span-98'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-99' style='margin-right: 0.05em;'>s</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-100' style='vertical-align: -0.4em;'>2</span></span></span></span><script type='math/tex' id='MathJax-Element-24'>s_2</script></var>
# :
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-101'><span class='MJXp-msubsup' id='MJXp-Span-102'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-103' style='margin-right: 0.05em;'>s</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-104' style='vertical-align: -0.4em;'>R</span></span></span></span><script type='math/tex' id='MathJax-Element-25'>s_R</script></var>
# </pre>
#
# <ul class='simple'>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-105'><span class='MJXp-mn' id='MJXp-Span-106'>1</span></span></span><script type='math/tex' id='MathJax-Element-26'>1</script></var> 行目には、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-107'><span class='MJXp-mn' id='MJXp-Span-108'>3</span></span></span><script type='math/tex' id='MathJax-Element-27'>3</script></var> つの整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-109'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-110'>R</span><span class='MJXp-mo' id='MJXp-Span-111' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-112'>3</span><span class='MJXp-mo' id='MJXp-Span-113' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-114'>R</span><span class='MJXp-mo' id='MJXp-Span-115' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-116'>500</span><span class='MJXp-mo' id='MJXp-Span-117' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-28'>R (3 ≦ R ≦ 500)</script></var>, <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-118'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-119'>C</span><span class='MJXp-mo' id='MJXp-Span-120' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-121'>3</span><span class='MJXp-mo' id='MJXp-Span-122' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-123'>C</span><span class='MJXp-mo' id='MJXp-Span-124' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-125'>500</span><span class='MJXp-mo' id='MJXp-Span-126' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-29'>C (3 ≦ C ≦ 500)</script></var>, <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-127'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-128'>K</span><span class='MJXp-mo' id='MJXp-Span-129' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-130'>2</span><span class='MJXp-mo' id='MJXp-Span-131' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-132'>K</span><span class='MJXp-mo' id='MJXp-Span-133' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-134'>500</span><span class='MJXp-mo' id='MJXp-Span-135' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-30'>K (2 ≦ K ≦ 500)</script></var> が空白区切りで書かれている。これは、長方形領域が縦 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-136'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-137'>R</span></span></span><script type='math/tex' id='MathJax-Element-31'>R</script></var> 行、横 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-138'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-139'>C</span></span></span><script type='math/tex' id='MathJax-Element-32'>C</script></var> 列あることを表す。<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-140'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-141'>K</span></span></span><script type='math/tex' id='MathJax-Element-33'>K</script></var> は文中で定められた整数である。</li>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-142'><span class='MJXp-mn' id='MJXp-Span-143'>2</span></span></span><script type='math/tex' id='MathJax-Element-34'>2</script></var> 行目から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-144'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-145'>R</span></span></span><script type='math/tex' id='MathJax-Element-35'>R</script></var> 行には、マスに関する情報が与えられる。<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-146'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-147'>R</span></span></span><script type='math/tex' id='MathJax-Element-36'>R</script></var> 行のうち <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-148'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-149'>i</span><span class='MJXp-mo' id='MJXp-Span-150' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-151'>1</span><span class='MJXp-mo' id='MJXp-Span-152' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-153'>i</span><span class='MJXp-mo' id='MJXp-Span-154' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-155'>R</span><span class='MJXp-mo' id='MJXp-Span-156' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-37'>i (1 ≦ i ≦ R)</script></var> 行目には、長さ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-157'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-158'>C</span></span></span><script type='math/tex' id='MathJax-Element-38'>C</script></var> の文字列 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-159'><span class='MJXp-msubsup' id='MJXp-Span-160'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-161' style='margin-right: 0.05em;'>s</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-162' style='vertical-align: -0.4em;'>i</span></span></span></span><script type='math/tex' id='MathJax-Element-39'>s_i</script></var> が与えられる。文字列 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-163'><span class='MJXp-msubsup' id='MJXp-Span-164'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-165' style='margin-right: 0.05em;'>s</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-166' style='vertical-align: -0.4em;'>i</span></span></span></span><script type='math/tex' id='MathJax-Element-40'>s_i</script></var> は <code>o</code>, <code>x</code> の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-167'><span class='MJXp-mn' id='MJXp-Span-168'>2</span></span></span><script type='math/tex' id='MathJax-Element-41'>2</script></var> 種類の文字でのみ構成されており、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-169'><span class='MJXp-msubsup' id='MJXp-Span-170'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-171' style='margin-right: 0.05em;'>s</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-172' style='vertical-align: -0.4em;'>i</span></span></span></span><script type='math/tex' id='MathJax-Element-42'>s_i</script></var> の左から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-173'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-174'>j</span><span class='MJXp-mo' id='MJXp-Span-175' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-176'>1</span><span class='MJXp-mo' id='MJXp-Span-177' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-178'>j</span><span class='MJXp-mo' id='MJXp-Span-179' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-180'>C</span><span class='MJXp-mo' id='MJXp-Span-181' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-43'>j (1 ≦ j ≦ C)</script></var> 文字目の文字が <code>o</code> ならマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-182'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-183'>i</span></span></span><script type='math/tex' id='MathJax-Element-44'>i</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-184'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-185'>j</span></span></span><script type='math/tex' id='MathJax-Element-45'>j</script></var>) が白いマスであることを、<code>x</code> ならマス (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-186'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-187'>i</span></span></span><script type='math/tex' id='MathJax-Element-46'>i</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-188'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-189'>j</span></span></span><script type='math/tex' id='MathJax-Element-47'>j</script></var>) が黒いマスであることを表す。</li>
#
# </ul>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>部分点</h3>
#
# <p>この問題には部分点が設定されている。</p>
#
# <ul class='simple'>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-190'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-191'>R</span><span class='MJXp-mo' id='MJXp-Span-192' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-193'>50</span></span></span><script type='math/tex' id='MathJax-Element-48'>R ≦ 50</script></var> かつ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-194'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-195'>C</span><span class='MJXp-mo' id='MJXp-Span-196' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-197'>50</span></span></span><script type='math/tex' id='MathJax-Element-49'>C ≦ 50</script></var> を満たすデータセット <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-198'><span class='MJXp-mn' id='MJXp-Span-199'>1</span></span></span><script type='math/tex' id='MathJax-Element-50'>1</script></var> に正解した場合は、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-200'><span class='MJXp-mn' id='MJXp-Span-201'>30</span></span></span><script type='math/tex' id='MathJax-Element-51'>30</script></var> 点が与えられる。</li>
#
# </ul>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力</h3>
#
# <p>緑色の塗り方の総数を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-202'><span class='MJXp-mn' id='MJXp-Span-203'>1</span></span></span><script type='math/tex' id='MathJax-Element-52'>1</script></var> 行に出力せよ。出力の末尾に改行を入れること。</p>
#
# </section>
# </div>
# </div>
# <hr>
# <div class='part'>
#
# <section>
# <h3>入力例1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample0'>4 5 2
# xoooo
# oooox
# ooooo
# oxxoo
# </pre>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力例1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample1'>3
# </pre>
#
# <p>以下の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-204'><span class='MJXp-mn' id='MJXp-Span-205'>3</span></span></span><script type='math/tex' id='MathJax-Element-53'>3</script></var> 通りが考えられます (<code>o</code> は白いマス、<code>x</code> は黒いマス、<code>*</code> は緑色のマスを表します)。</p>
#
# <table border='1'>
#
# <tbody><tr><td>x</td><td>*</td><td>o</td><td>o</td><td>o</td></tr>
# <tr><td>*</td><td>*</td><td>*</td><td>o</td><td>x</td></tr>
# <tr><td>o</td><td>*</td><td>o</td><td>o</td><td>o</td></tr>
# <tr><td>o</td><td>x</td><td>x</td><td>o</td><td>o</td></tr>
#
# </tbody></table>
#
# <p></p>
#
# <table border='1'>
#
# <tbody><tr><td>x</td><td>o</td><td>*</td><td>o</td><td>o</td></tr>
# <tr><td>o</td><td>*</td><td>*</td><td>*</td><td>x</td></tr>
# <tr><td>o</td><td>o</td><td>*</td><td>o</td><td>o</td></tr>
# <tr><td>o</td><td>x</td><td>x</td><td>o</td><td>o</td></tr>
#
# </tbody></table>
#
# <p></p>
#
# <table border='1'>
#
# <tbody><tr><td>x</td><td>o</td><td>o</td><td>o</td><td>o</td></tr>
# <tr><td>o</td><td>o</td><td>o</td><td>*</td><td>x</td></tr>
# <tr><td>o</td><td>o</td><td>*</td><td>*</td><td>*</td></tr>
# <tr><td>o</td><td>x</td><td>x</td><td>*</td><td>o</td></tr>
#
# </tbody></table>
#
# </section>
# </div>
# <hr>
# <div class='part'>
#
# <section>
# <h3>入力例2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample2'>4 5 2
# ooooo
# oxoox
# oooox
# oxxoo
# </pre>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力例2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample3'>0
# </pre>
#
# </section>
# </div>
#
# <hr>
# <div class='part'>
#
# <section>
# <h3>入力例3 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample4' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample4' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample4'>8 6 3
# oooooo
# oooooo
# oooooo
# oooooo
# oxoooo
# oooooo
# oooooo
# oooooo
# </pre>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力例3 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample5' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample5' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample5'>4
# </pre>
#
# </section>
# </div>
# </div>
#
# </div>
#
#
#
#
# </div>
# </div>
#
#
#
# <hr>
