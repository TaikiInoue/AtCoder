# %% [markdown]
# <span class='h2'>E - Sum Equals Xor</span>
# <hr>
# <p>Time Limit: 2 sec / Memory Limit: 1024 MB</p>
#
# <div id='task-statement'>
# <span class='lang'>
# <span class='lang-ja'>
# <p>配点 : <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mn' id='MJXp-Span-2'>500</span></span></span><script type='math/tex' id='MathJax-Element-1'>500</script></var> 点</p>
#
# <div class='part'>
# <section>
# <h3>問題文</h3><p>正整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-3'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-4'>L</span></span></span><script type='math/tex' id='MathJax-Element-2'>L</script></var> が二進数表記で与えられます。
# 以下の条件を満たす非負整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-6'>a</span><span class='MJXp-mo' id='MJXp-Span-7' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-8'>b</span></span></span><script type='math/tex' id='MathJax-Element-3'>a, b</script></var> の組 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-9'><span class='MJXp-mo' id='MJXp-Span-10' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-11'>a</span><span class='MJXp-mo' id='MJXp-Span-12' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-13'>b</span><span class='MJXp-mo' id='MJXp-Span-14' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-4'>(a, b)</script></var> がいくつ存在するか求めてください:</p>
# <ul>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-15'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-16'>a</span><span class='MJXp-mo' id='MJXp-Span-17' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-18'>b</span><span class='MJXp-mo' id='MJXp-Span-19' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-20'>L</span></span></span><script type='math/tex' id='MathJax-Element-5'>a + b \leq L</script></var></li>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-21'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-22'>a</span><span class='MJXp-mo' id='MJXp-Span-23' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-24'>b</span><span class='MJXp-mo' id='MJXp-Span-25' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-26'>a</span><span class='MJXp-mstyle' id='MJXp-Span-27'><span class='MJXp-mtext' id='MJXp-Span-28'>&nbsp;XOR&nbsp;</span></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-29'>b</span></span></span><script type='math/tex' id='MathJax-Element-6'>a + b = a \mbox{ XOR } b</script></var></li>
# </ul>
# <p>ただし、この値は非常に大きくなることがあるので、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-30'><span class='MJXp-msubsup' id='MJXp-Span-31'><span class='MJXp-mn' id='MJXp-Span-32' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-33' style='vertical-align: 0.5em;'>9</span></span><span class='MJXp-mo' id='MJXp-Span-34' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-35'>7</span></span></span><script type='math/tex' id='MathJax-Element-7'>10^9 + 7</script></var> で割った余りを出力してください。</p>
# <p></p><details> <summary style='display: list-item; outline: none;'>XOR とは</summary><p></p>
# <p>整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-36'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-37'>A</span><span class='MJXp-mo' id='MJXp-Span-38' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-39'>B</span></span></span><script type='math/tex' id='MathJax-Element-8'>A, B</script></var> のビットごとの排他的論理和 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-40'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-41'>a</span><span class='MJXp-mstyle' id='MJXp-Span-42'><span class='MJXp-mtext' id='MJXp-Span-43'>&nbsp;XOR&nbsp;</span></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-44'>b</span></span></span><script type='math/tex' id='MathJax-Element-9'>a \mbox{ XOR } b</script></var> は、以下のように定義されます。</p>
# <p><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-45'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-46'>a</span><span class='MJXp-mstyle' id='MJXp-Span-47'><span class='MJXp-mtext' id='MJXp-Span-48'>&nbsp;XOR&nbsp;</span></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-49'>b</span></span></span><script type='math/tex' id='MathJax-Element-10'>a \mbox{ XOR } b</script></var> を二進数表記した際の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-50'><span class='MJXp-msubsup' id='MJXp-Span-51'><span class='MJXp-mn' id='MJXp-Span-52' style='margin-right: 0.05em;'>2</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-53' style='vertical-align: 0.5em;'>k</span></span></span></span><script type='math/tex' id='MathJax-Element-11'>2^k</script></var> (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-54'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-55'>k</span><span class='MJXp-mo' id='MJXp-Span-56' style='margin-left: 0.333em; margin-right: 0.333em;'>≥</span><span class='MJXp-mn' id='MJXp-Span-57'>0</span></span></span><script type='math/tex' id='MathJax-Element-12'>k \geq 0</script></var>) の位の数は、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-58'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-59'>A</span><span class='MJXp-mo' id='MJXp-Span-60' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-61'>B</span></span></span><script type='math/tex' id='MathJax-Element-13'>A, B</script></var> を二進数表記した際の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-62'><span class='MJXp-msubsup' id='MJXp-Span-63'><span class='MJXp-mn' id='MJXp-Span-64' style='margin-right: 0.05em;'>2</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-65' style='vertical-align: 0.5em;'>k</span></span></span></span><script type='math/tex' id='MathJax-Element-14'>2^k</script></var> の位の数のうち一方のみが <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-66'><span class='MJXp-mn' id='MJXp-Span-67'>1</span></span></span><script type='math/tex' id='MathJax-Element-15'>1</script></var> であれば <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-68'><span class='MJXp-mn' id='MJXp-Span-69'>1</span></span></span><script type='math/tex' id='MathJax-Element-16'>1</script></var>、そうでなければ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-70'><span class='MJXp-mn' id='MJXp-Span-71'>0</span></span></span><script type='math/tex' id='MathJax-Element-17'>0</script></var> である。
# 例えば、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-72'><span class='MJXp-mn' id='MJXp-Span-73'>3</span><span class='MJXp-mstyle' id='MJXp-Span-74'><span class='MJXp-mtext' id='MJXp-Span-75'>&nbsp;XOR&nbsp;</span></span><span class='MJXp-mn' id='MJXp-Span-76'>5</span><span class='MJXp-mo' id='MJXp-Span-77' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mn' id='MJXp-Span-78'>6</span></span></span><script type='math/tex' id='MathJax-Element-18'>3 \mbox{ XOR } 5 = 6</script></var> となります (二進数表記すると: <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-79'><span class='MJXp-mn' id='MJXp-Span-80'>011</span><span class='MJXp-mstyle' id='MJXp-Span-81'><span class='MJXp-mtext' id='MJXp-Span-82'>&nbsp;XOR&nbsp;</span></span><span class='MJXp-mn' id='MJXp-Span-83'>101</span><span class='MJXp-mo' id='MJXp-Span-84' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mn' id='MJXp-Span-85'>110</span></span></span><script type='math/tex' id='MathJax-Element-19'>011 \mbox{ XOR } 101 = 110</script></var>)。</p>
# <p></p></details><p></p>
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>制約</h3><ul>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-86'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-87'>L</span></span></span><script type='math/tex' id='MathJax-Element-20'>L</script></var>は二進数表記で与えられ、先頭文字は必ず <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-88'><span class='MJXp-mn' id='MJXp-Span-89'>1</span></span></span><script type='math/tex' id='MathJax-Element-21'>1</script></var> である</li>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-90'><span class='MJXp-mn' id='MJXp-Span-91'>1</span><span class='MJXp-mo' id='MJXp-Span-92' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-93'>L</span><span class='MJXp-mo' id='MJXp-Span-94' style='margin-left: 0.333em; margin-right: 0.333em;'>&lt;</span><span class='MJXp-msubsup' id='MJXp-Span-95'><span class='MJXp-mn' id='MJXp-Span-96' style='margin-right: 0.05em;'>2</span><span class='MJXp-mrow MJXp-script' id='MJXp-Span-97' style='vertical-align: 0.5em;'><span class='MJXp-mn' id='MJXp-Span-98'>100</span><span class='MJXp-mo' id='MJXp-Span-99'>,</span><span class='MJXp-mn' id='MJXp-Span-100'>001</span></span></span></span></span><script type='math/tex' id='MathJax-Element-22'>1 \leq L < 2^{100,001}</script></var></li>
# </ul>
# </section>
# </div>
#
# <hr>
#
# <div class='io-style'>
# <div class='part'>
# <section>
# <h3>入力</h3><p>入力は以下の形式で標準入力から与えられる。</p>
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-101'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-102'>L</span></span></span><script type='math/tex' id='MathJax-Element-23'>L</script></var>
# </pre>
#
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力</h3><p>条件を満たす組 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-103'><span class='MJXp-mo' id='MJXp-Span-104' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-105'>a</span><span class='MJXp-mo' id='MJXp-Span-106' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-107'>b</span><span class='MJXp-mo' id='MJXp-Span-108' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-24'>(a, b)</script></var> の個数を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-109'><span class='MJXp-msubsup' id='MJXp-Span-110'><span class='MJXp-mn' id='MJXp-Span-111' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-112' style='vertical-align: 0.5em;'>9</span></span><span class='MJXp-mo' id='MJXp-Span-113' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-114'>7</span></span></span><script type='math/tex' id='MathJax-Element-25'>10^9 + 7</script></var> で割った余りを出力せよ。</p>
# </section>
# </div>
# </div>
#
# <hr>
#
# <div class='part'>
# <section>
# <h3>入力例 1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample0'>10
# </pre>
#
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力例 1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample1'>5
# </pre>
#
# <p>条件を満たす <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-115'><span class='MJXp-mo' id='MJXp-Span-116' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-117'>a</span><span class='MJXp-mo' id='MJXp-Span-118' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-119'>b</span><span class='MJXp-mo' id='MJXp-Span-120' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-26'>(a, b)</script></var> としては <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-121'><span class='MJXp-mo' id='MJXp-Span-122' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-123'>0</span><span class='MJXp-mo' id='MJXp-Span-124' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-125'>0</span><span class='MJXp-mo' id='MJXp-Span-126' style='margin-left: 0em; margin-right: 0em;'>)</span><span class='MJXp-mo' id='MJXp-Span-127' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mo' id='MJXp-Span-128' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-129'>0</span><span class='MJXp-mo' id='MJXp-Span-130' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-131'>1</span><span class='MJXp-mo' id='MJXp-Span-132' style='margin-left: 0em; margin-right: 0em;'>)</span><span class='MJXp-mo' id='MJXp-Span-133' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mo' id='MJXp-Span-134' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-135'>1</span><span class='MJXp-mo' id='MJXp-Span-136' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-137'>0</span><span class='MJXp-mo' id='MJXp-Span-138' style='margin-left: 0em; margin-right: 0em;'>)</span><span class='MJXp-mo' id='MJXp-Span-139' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mo' id='MJXp-Span-140' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-141'>0</span><span class='MJXp-mo' id='MJXp-Span-142' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-143'>2</span><span class='MJXp-mo' id='MJXp-Span-144' style='margin-left: 0em; margin-right: 0em;'>)</span><span class='MJXp-mo' id='MJXp-Span-145' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mo' id='MJXp-Span-146' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-147'>2</span><span class='MJXp-mo' id='MJXp-Span-148' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-149'>0</span><span class='MJXp-mo' id='MJXp-Span-150' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-27'>(0, 0), (0, 1), (1, 0), (0, 2), (2, 0)</script></var> の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-151'><span class='MJXp-mn' id='MJXp-Span-152'>5</span></span></span><script type='math/tex' id='MathJax-Element-28'>5</script></var> つが考えられます。</p>
# </section>
# </div>
#
# <hr>
#
# <div class='part'>
# <section>
# <h3>入力例 2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample2'>1111111111111111111
# </pre>
#
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力例 2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample3'>162261460
# </pre></section>
# </div>
# </span>

# %%
from ipywidgets import Textarea
import sys
sys.path.append('../../..')

from utils.multi_line_input import multi_line_input
text_area = Textarea()
input = multi_line_input()

display(text_area)
