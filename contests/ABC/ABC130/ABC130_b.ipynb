# %% [markdown]
# <span class='h2'>B - Bounding</span>
# <hr>
# <p>Time Limit: 2 sec / Memory Limit: 1024 MB</p>
#
# <div id='task-statement'>
# <span class='lang'>
# <span class='lang-ja'>
# <p>配点 : <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mn' id='MJXp-Span-2'>200</span></span></span><span id='MathJax-Element-1-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-1' class='mjx-math'><span id='MJXc-Node-2' class='mjx-mrow'><span id='MJXc-Node-3' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>200</span></span></span></span></span><script type='math/tex' id='MathJax-Element-1'>200</script></var> 点</p>
#
# <div class='part'>
# <section>
# <h3>問題文</h3><p>数直線上を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-3'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-4'>N</span><span class='MJXp-mo' id='MJXp-Span-5' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-6'>1</span></span></span><span id='MathJax-Element-2-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-4' class='mjx-math'><span id='MJXc-Node-5' class='mjx-mrow'><span id='MJXc-Node-6' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.085em;'>N</span></span><span id='MJXc-Node-7' class='mjx-mo MJXc-space2'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.316em; padding-bottom: 0.441em;'>+</span></span><span id='MJXc-Node-8' class='mjx-mn MJXc-space2'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span></span></span></span><script type='math/tex' id='MathJax-Element-2'>N + 1</script></var> 回跳ねるボールがあり、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-7'><span class='MJXp-mn' id='MJXp-Span-8'>1</span></span></span><span id='MathJax-Element-3-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-9' class='mjx-math'><span id='MJXc-Node-10' class='mjx-mrow'><span id='MJXc-Node-11' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span></span></span></span><script type='math/tex' id='MathJax-Element-3'>1</script></var> 回目は 座標 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-9'><span class='MJXp-msubsup' id='MJXp-Span-10'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-11' style='margin-right: 0.05em;'>D</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-12' style='vertical-align: -0.4em;'>1</span></span><span class='MJXp-mo' id='MJXp-Span-13' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mn' id='MJXp-Span-14'>0</span></span></span><span id='MathJax-Element-4-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-12' class='mjx-math'><span id='MJXc-Node-13' class='mjx-mrow'><span id='MJXc-Node-14' class='mjx-msubsup'><span class='mjx-base'><span id='MJXc-Node-15' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em;'>D</span></span></span><span class='mjx-sub' style='font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;'><span id='MJXc-Node-16' class='mjx-mn' style=''><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span></span></span><span id='MJXc-Node-17' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.066em; padding-bottom: 0.316em;'>=</span></span><span id='MJXc-Node-18' class='mjx-mn MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>0</span></span></span></span></span><script type='math/tex' id='MathJax-Element-4'>D_1 = 0</script></var>,  <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-15'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-16'>i</span></span></span><span id='MathJax-Element-5-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-19' class='mjx-math'><span id='MJXc-Node-20' class='mjx-mrow'><span id='MJXc-Node-21' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.316em;'>i</span></span></span></span></span><script type='math/tex' id='MathJax-Element-5'>i</script></var> 回目は 座標 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-17'><span class='MJXp-msubsup' id='MJXp-Span-18'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-19' style='margin-right: 0.05em;'>D</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-20' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-21' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-msubsup' id='MJXp-Span-22'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-23' style='margin-right: 0.05em;'>D</span><span class='MJXp-mrow MJXp-script' id='MJXp-Span-24' style='vertical-align: -0.4em;'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-25'>i</span><span class='MJXp-mo' id='MJXp-Span-26'>−</span><span class='MJXp-mn' id='MJXp-Span-27'>1</span></span></span><span class='MJXp-mo' id='MJXp-Span-28' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-msubsup' id='MJXp-Span-29'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-30' style='margin-right: 0.05em;'>L</span><span class='MJXp-mrow MJXp-script' id='MJXp-Span-31' style='vertical-align: -0.4em;'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-32'>i</span><span class='MJXp-mo' id='MJXp-Span-33'>−</span><span class='MJXp-mn' id='MJXp-Span-34'>1</span></span></span><span class='MJXp-mo' id='MJXp-Span-35' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-36'>2</span><span class='MJXp-mo' id='MJXp-Span-37' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-38'>i</span><span class='MJXp-mo' id='MJXp-Span-39' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-40'>N</span><span class='MJXp-mo' id='MJXp-Span-41' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-42'>1</span><span class='MJXp-mo' id='MJXp-Span-43' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><span id='MathJax-Element-6-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-22' class='mjx-math'><span id='MJXc-Node-23' class='mjx-mrow'><span id='MJXc-Node-24' class='mjx-msubsup'><span class='mjx-base'><span id='MJXc-Node-25' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em;'>D</span></span></span><span class='mjx-sub' style='font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;'><span id='MJXc-Node-26' class='mjx-mi' style=''><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.316em;'>i</span></span></span></span><span id='MJXc-Node-27' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.066em; padding-bottom: 0.316em;'>=</span></span><span id='MJXc-Node-28' class='mjx-msubsup MJXc-space3'><span class='mjx-base'><span id='MJXc-Node-29' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em;'>D</span></span></span><span class='mjx-sub' style='font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;'><span id='MJXc-Node-30' class='mjx-texatom' style=''><span id='MJXc-Node-31' class='mjx-mrow'><span id='MJXc-Node-32' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.316em;'>i</span></span><span id='MJXc-Node-33' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.316em; padding-bottom: 0.441em;'>−</span></span><span id='MJXc-Node-34' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span></span></span></span></span><span id='MJXc-Node-35' class='mjx-mo MJXc-space2'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.316em; padding-bottom: 0.441em;'>+</span></span><span id='MJXc-Node-36' class='mjx-msubsup MJXc-space2'><span class='mjx-base'><span id='MJXc-Node-37' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em;'>L</span></span></span><span class='mjx-sub' style='font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;'><span id='MJXc-Node-38' class='mjx-texatom' style=''><span id='MJXc-Node-39' class='mjx-mrow'><span id='MJXc-Node-40' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.316em;'>i</span></span><span id='MJXc-Node-41' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.316em; padding-bottom: 0.441em;'>−</span></span><span id='MJXc-Node-42' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span></span></span></span></span><span id='MJXc-Node-43' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.441em; padding-bottom: 0.566em;'>(</span></span><span id='MJXc-Node-44' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>2</span></span><span id='MJXc-Node-45' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.503em;'>≤</span></span><span id='MJXc-Node-46' class='mjx-mi MJXc-space3'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.316em;'>i</span></span><span id='MJXc-Node-47' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.503em;'>≤</span></span><span id='MJXc-Node-48' class='mjx-mi MJXc-space3'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.085em;'>N</span></span><span id='MJXc-Node-49' class='mjx-mo MJXc-space2'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.316em; padding-bottom: 0.441em;'>+</span></span><span id='MJXc-Node-50' class='mjx-mn MJXc-space2'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span><span id='MJXc-Node-51' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.441em; padding-bottom: 0.566em;'>)</span></span></span></span></span><script type='math/tex' id='MathJax-Element-6'>D_i = D_{i-1} + L_{i-1} (2 \leq i \leq N+1)</script></var> で跳ねます。</p>
# <p>数直線の座標が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-44'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-45'>X</span></span></span><span id='MathJax-Element-7-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-52' class='mjx-math'><span id='MJXc-Node-53' class='mjx-mrow'><span id='MJXc-Node-54' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.024em;'>X</span></span></span></span></span><script type='math/tex' id='MathJax-Element-7'>X</script></var> 以下の領域でボールが跳ねる回数は何回でしょうか。</p>
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>制約</h3><ul>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-46'><span class='MJXp-mn' id='MJXp-Span-47'>1</span><span class='MJXp-mo' id='MJXp-Span-48' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-49'>N</span><span class='MJXp-mo' id='MJXp-Span-50' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mn' id='MJXp-Span-51'>100</span></span></span><span id='MathJax-Element-8-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-55' class='mjx-math'><span id='MJXc-Node-56' class='mjx-mrow'><span id='MJXc-Node-57' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span><span id='MJXc-Node-58' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.503em;'>≤</span></span><span id='MJXc-Node-59' class='mjx-mi MJXc-space3'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.085em;'>N</span></span><span id='MJXc-Node-60' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.503em;'>≤</span></span><span id='MJXc-Node-61' class='mjx-mn MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>100</span></span></span></span></span><script type='math/tex' id='MathJax-Element-8'>1 \leq N \leq 100</script></var></li>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-52'><span class='MJXp-mn' id='MJXp-Span-53'>1</span><span class='MJXp-mo' id='MJXp-Span-54' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-msubsup' id='MJXp-Span-55'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-56' style='margin-right: 0.05em;'>L</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-57' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-58' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mn' id='MJXp-Span-59'>100</span></span></span><span id='MathJax-Element-9-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-62' class='mjx-math'><span id='MJXc-Node-63' class='mjx-mrow'><span id='MJXc-Node-64' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span><span id='MJXc-Node-65' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.503em;'>≤</span></span><span id='MJXc-Node-66' class='mjx-msubsup MJXc-space3'><span class='mjx-base'><span id='MJXc-Node-67' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em;'>L</span></span></span><span class='mjx-sub' style='font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;'><span id='MJXc-Node-68' class='mjx-mi' style=''><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.316em;'>i</span></span></span></span><span id='MJXc-Node-69' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.503em;'>≤</span></span><span id='MJXc-Node-70' class='mjx-mn MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>100</span></span></span></span></span><script type='math/tex' id='MathJax-Element-9'>1 \leq L_i \leq 100</script></var></li>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-60'><span class='MJXp-mn' id='MJXp-Span-61'>1</span><span class='MJXp-mo' id='MJXp-Span-62' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-63'>X</span><span class='MJXp-mo' id='MJXp-Span-64' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mn' id='MJXp-Span-65'>10000</span></span></span><span id='MathJax-Element-10-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-71' class='mjx-math'><span id='MJXc-Node-72' class='mjx-mrow'><span id='MJXc-Node-73' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span><span id='MJXc-Node-74' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.503em;'>≤</span></span><span id='MJXc-Node-75' class='mjx-mi MJXc-space3'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.024em;'>X</span></span><span id='MJXc-Node-76' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.503em;'>≤</span></span><span id='MJXc-Node-77' class='mjx-mn MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>10000</span></span></span></span></span><script type='math/tex' id='MathJax-Element-10'>1 \leq X \leq 10000</script></var></li>
# <li>入力は全て整数である</li>
# </ul>
# </section>
# </div>
#
# <hr>
#
# <div class='io-style'>
# <div class='part'>
# <section>
# <h3>入力</h3><p>入力は以下の形式で標準入力から与えられる。</p>
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-66'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-67'>N</span></span></span><span id='MathJax-Element-11-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-78' class='mjx-math'><span id='MJXc-Node-79' class='mjx-mrow'><span id='MJXc-Node-80' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.085em;'>N</span></span></span></span></span><script type='math/tex' id='MathJax-Element-11'>N</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-68'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-69'>X</span></span></span><span id='MathJax-Element-12-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-81' class='mjx-math'><span id='MJXc-Node-82' class='mjx-mrow'><span id='MJXc-Node-83' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.024em;'>X</span></span></span></span></span><script type='math/tex' id='MathJax-Element-12'>X</script></var>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-70'><span class='MJXp-msubsup' id='MJXp-Span-71'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-72' style='margin-right: 0.05em;'>L</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-73' style='vertical-align: -0.4em;'>1</span></span></span></span><span id='MathJax-Element-13-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-84' class='mjx-math'><span id='MJXc-Node-85' class='mjx-mrow'><span id='MJXc-Node-86' class='mjx-msubsup'><span class='mjx-base'><span id='MJXc-Node-87' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em;'>L</span></span></span><span class='mjx-sub' style='font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;'><span id='MJXc-Node-88' class='mjx-mn' style=''><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span></span></span></span></span></span><script type='math/tex' id='MathJax-Element-13'>L_1</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-74'><span class='MJXp-msubsup' id='MJXp-Span-75'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-76' style='margin-right: 0.05em;'>L</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-77' style='vertical-align: -0.4em;'>2</span></span></span></span><span id='MathJax-Element-14-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-89' class='mjx-math'><span id='MJXc-Node-90' class='mjx-mrow'><span id='MJXc-Node-91' class='mjx-msubsup'><span class='mjx-base'><span id='MJXc-Node-92' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em;'>L</span></span></span><span class='mjx-sub' style='font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;'><span id='MJXc-Node-93' class='mjx-mn' style=''><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>2</span></span></span></span></span></span></span><script type='math/tex' id='MathJax-Element-14'>L_2</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-78'><span class='MJXp-mo' id='MJXp-Span-79' style='margin-left: 0em; margin-right: 0.222em;'>.</span><span class='MJXp-mo' id='MJXp-Span-80' style='margin-left: 0em; margin-right: 0.222em;'>.</span><span class='MJXp-mo' id='MJXp-Span-81' style='margin-left: 0em; margin-right: 0.222em;'>.</span></span></span><span id='MathJax-Element-15-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-94' class='mjx-math'><span id='MJXc-Node-95' class='mjx-mrow'><span id='MJXc-Node-96' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.316em;'>.</span></span><span id='MJXc-Node-97' class='mjx-mo MJXc-space1'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.316em;'>.</span></span><span id='MJXc-Node-98' class='mjx-mo MJXc-space1'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.316em;'>.</span></span></span></span></span><script type='math/tex' id='MathJax-Element-15'>...</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-82'><span class='MJXp-msubsup' id='MJXp-Span-83'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-84' style='margin-right: 0.05em;'>L</span><span class='MJXp-mrow MJXp-script' id='MJXp-Span-85' style='vertical-align: -0.4em;'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-86'>N</span><span class='MJXp-mo' id='MJXp-Span-87'>−</span><span class='MJXp-mn' id='MJXp-Span-88'>1</span></span></span></span></span><span id='MathJax-Element-16-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-99' class='mjx-math'><span id='MJXc-Node-100' class='mjx-mrow'><span id='MJXc-Node-101' class='mjx-msubsup'><span class='mjx-base'><span id='MJXc-Node-102' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em;'>L</span></span></span><span class='mjx-sub' style='font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;'><span id='MJXc-Node-103' class='mjx-texatom' style=''><span id='MJXc-Node-104' class='mjx-mrow'><span id='MJXc-Node-105' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.085em;'>N</span></span><span id='MJXc-Node-106' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.316em; padding-bottom: 0.441em;'>−</span></span><span id='MJXc-Node-107' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>1</span></span></span></span></span></span></span></span></span><script type='math/tex' id='MathJax-Element-16'>L_{N-1}</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-89'><span class='MJXp-msubsup' id='MJXp-Span-90'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-91' style='margin-right: 0.05em;'>L</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-92' style='vertical-align: -0.4em;'>N</span></span></span></span><span id='MathJax-Element-17-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-108' class='mjx-math'><span id='MJXc-Node-109' class='mjx-mrow'><span id='MJXc-Node-110' class='mjx-msubsup'><span class='mjx-base'><span id='MJXc-Node-111' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em;'>L</span></span></span><span class='mjx-sub' style='font-size: 70.7%; vertical-align: -0.212em; padding-right: 0.071em;'><span id='MJXc-Node-112' class='mjx-mi' style=''><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.085em;'>N</span></span></span></span></span></span></span><script type='math/tex' id='MathJax-Element-17'>L_N</script></var>
# </pre>
#
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力</h3><p>数直線の座標が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-93'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-94'>X</span></span></span><span id='MathJax-Element-18-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-113' class='mjx-math'><span id='MJXc-Node-114' class='mjx-mrow'><span id='MJXc-Node-115' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.441em; padding-bottom: 0.253em; padding-right: 0.024em;'>X</span></span></span></span></span><script type='math/tex' id='MathJax-Element-18'>X</script></var> 以下の領域でボールが跳ねる回数を出力せよ。</p>
# </section>
# </div>
# </div>
#
# <hr>
#
# <div class='part'>
# <section>
# <h3>入力例 1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample0'>3 6
# 3 4 5
# </pre>
#
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力例 1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample1'>2
# </pre>
#
# <p>ボールは順に座標 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-95'><span class='MJXp-mn' id='MJXp-Span-96'>0</span><span class='MJXp-mo' id='MJXp-Span-97' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-98'>3</span><span class='MJXp-mo' id='MJXp-Span-99' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-100'>7</span><span class='MJXp-mo' id='MJXp-Span-101' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-102'>12</span></span></span><span id='MathJax-Element-19-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-116' class='mjx-math'><span id='MJXc-Node-117' class='mjx-mrow'><span id='MJXc-Node-118' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>0</span></span><span id='MJXc-Node-119' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.566em;'>,</span></span><span id='MJXc-Node-120' class='mjx-mn MJXc-space1'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>3</span></span><span id='MJXc-Node-121' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.566em;'>,</span></span><span id='MJXc-Node-122' class='mjx-mn MJXc-space1'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>7</span></span><span id='MJXc-Node-123' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.566em;'>,</span></span><span id='MJXc-Node-124' class='mjx-mn MJXc-space1'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>12</span></span></span></span></span><script type='math/tex' id='MathJax-Element-19'>0, 3, 7, 12</script></var> で跳ねるので、座標 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-103'><span class='MJXp-mn' id='MJXp-Span-104'>6</span></span></span><span id='MathJax-Element-20-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-125' class='mjx-math'><span id='MJXc-Node-126' class='mjx-mrow'><span id='MJXc-Node-127' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>6</span></span></span></span></span><script type='math/tex' id='MathJax-Element-20'>6</script></var> 以下の領域で跳ねる回数は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-105'><span class='MJXp-mn' id='MJXp-Span-106'>2</span></span></span><span id='MathJax-Element-21-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-128' class='mjx-math'><span id='MJXc-Node-129' class='mjx-mrow'><span id='MJXc-Node-130' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>2</span></span></span></span></span><script type='math/tex' id='MathJax-Element-21'>2</script></var> 回です。</p>
# </section>
# </div>
#
# <hr>
#
# <div class='part'>
# <section>
# <h3>入力例 2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample2'>4 9
# 3 3 3 3
# </pre>
#
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力例 2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample3'>4
# </pre>
#
# <p>ボールは順に座標 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-107'><span class='MJXp-mn' id='MJXp-Span-108'>0</span><span class='MJXp-mo' id='MJXp-Span-109' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-110'>3</span><span class='MJXp-mo' id='MJXp-Span-111' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-112'>6</span><span class='MJXp-mo' id='MJXp-Span-113' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-114'>9</span><span class='MJXp-mo' id='MJXp-Span-115' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-116'>12</span></span></span><span id='MathJax-Element-22-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-131' class='mjx-math'><span id='MJXc-Node-132' class='mjx-mrow'><span id='MJXc-Node-133' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>0</span></span><span id='MJXc-Node-134' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.566em;'>,</span></span><span id='MJXc-Node-135' class='mjx-mn MJXc-space1'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>3</span></span><span id='MJXc-Node-136' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.566em;'>,</span></span><span id='MJXc-Node-137' class='mjx-mn MJXc-space1'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>6</span></span><span id='MJXc-Node-138' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.566em;'>,</span></span><span id='MJXc-Node-139' class='mjx-mn MJXc-space1'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>9</span></span><span id='MJXc-Node-140' class='mjx-mo'><span class='mjx-char MJXc-TeX-main-R' style='margin-top: -0.184em; padding-bottom: 0.566em;'>,</span></span><span id='MJXc-Node-141' class='mjx-mn MJXc-space1'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>12</span></span></span></span></span><script type='math/tex' id='MathJax-Element-22'>0, 3, 6, 9, 12</script></var> で跳ねるので、座標 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-117'><span class='MJXp-mn' id='MJXp-Span-118'>9</span></span></span><span id='MathJax-Element-23-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-142' class='mjx-math'><span id='MJXc-Node-143' class='mjx-mrow'><span id='MJXc-Node-144' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.378em;'>9</span></span></span></span></span><script type='math/tex' id='MathJax-Element-23'>9</script></var> 以下の領域で跳ねる回数は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-119'><span class='MJXp-mn' id='MJXp-Span-120'>4</span></span></span><span id='MathJax-Element-24-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;'><span id='MJXc-Node-145' class='mjx-math'><span id='MJXc-Node-146' class='mjx-mrow'><span id='MJXc-Node-147' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.378em; padding-bottom: 0.316em;'>4</span></span></span></span></span><script type='math/tex' id='MathJax-Element-24'>4</script></var> 回です。</p></section>
# </div>
# </span>
