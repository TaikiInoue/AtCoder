# %% [markdown]
# <span class='h2'>D - 阿弥陀</span>
# <hr>
# <p>Time Limit: 4 sec / Memory Limit: 256 MB</p>
#
# <div id='task-statement'>
# <div id='task-statement'>
# <div class='part'>
#
# <section>
# <h3>問題文</h3>
#
# <p>古くより伝わる日本の伝統的なくじ引き、あみだくじをご存知だろうか？</p>
#
# <p>あみだくじを行うときは、まず <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-2'>N</span></span></span><script type='math/tex' id='MathJax-Element-1'>N</script></var> 本の平行な縦線を引く。次に、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-3'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-4'>M</span></span></span><script type='math/tex' id='MathJax-Element-2'>M</script></var> 本の横線をその中に引いていく。それぞれの横線は隣り合う <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mn' id='MJXp-Span-6'>2</span></span></span><script type='math/tex' id='MathJax-Element-3'>2</script></var> 本の縦線を結ぶように引かなければならず、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-7'><span class='MJXp-mn' id='MJXp-Span-8'>2</span></span></span><script type='math/tex' id='MathJax-Element-4'>2</script></var> 本以上の横線がまったく同じ高さにあってはいけない。ここでは、上から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-9'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-10'>i</span></span></span><script type='math/tex' id='MathJax-Element-5'>i</script></var> (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-11'><span class='MJXp-mn' id='MJXp-Span-12'>1</span><span class='MJXp-mspace' id='MJXp-Span-13' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-14' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-15' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-16'>i</span><span class='MJXp-mspace' id='MJXp-Span-17' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-18' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-19' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-20'>M</span></span></span><script type='math/tex' id='MathJax-Element-6'>1\,≦\,i\,≦\,M</script></var>) 番目にある横線が、左から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-21'><span class='MJXp-msubsup' id='MJXp-Span-22'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-23' style='margin-right: 0.05em;'>A</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-24' style='vertical-align: -0.4em;'>i</span></span></span></span><script type='math/tex' id='MathJax-Element-7'>A_i</script></var> (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-25'><span class='MJXp-mn' id='MJXp-Span-26'>1</span><span class='MJXp-mspace' id='MJXp-Span-27' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-28' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-29' style='width: 0.167em; height: 0em;'></span><span class='MJXp-msubsup' id='MJXp-Span-30'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-31' style='margin-right: 0.05em;'>A</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-32' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-33' style='margin-left: 0.333em; margin-right: 0.333em;'>&lt;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-34'>N</span></span></span><script type='math/tex' id='MathJax-Element-8'>1\,≦\,A_i < N</script></var>) 番目の縦線と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-35'><span class='MJXp-msubsup' id='MJXp-Span-36'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-37' style='margin-right: 0.05em;'>A</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-38' style='vertical-align: -0.4em;'>i</span></span><span class='MJXp-mo' id='MJXp-Span-39' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-40'>1</span></span></span><script type='math/tex' id='MathJax-Element-9'>A_i + 1</script></var> 番目の縦線を結んでいるとしよう。</p>
#
# <p><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-41'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-42'>N</span><span class='MJXp-mo' id='MJXp-Span-43' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mn' id='MJXp-Span-44'>5</span></span></span><script type='math/tex' id='MathJax-Element-10'>N = 5</script></var>, <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-45'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-46'>M</span><span class='MJXp-mo' id='MJXp-Span-47' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mn' id='MJXp-Span-48'>7</span></span></span><script type='math/tex' id='MathJax-Element-11'>M = 7</script></var>, <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-49'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-50'>A</span><span class='MJXp-mo' id='MJXp-Span-51' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mo' id='MJXp-Span-52' style='margin-left: 0em; margin-right: 0em;'>{</span><span class='MJXp-mn' id='MJXp-Span-53'>1</span><span class='MJXp-mo' id='MJXp-Span-54' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-55'>4</span><span class='MJXp-mo' id='MJXp-Span-56' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-57'>3</span><span class='MJXp-mo' id='MJXp-Span-58' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-59'>4</span><span class='MJXp-mo' id='MJXp-Span-60' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-61'>2</span><span class='MJXp-mo' id='MJXp-Span-62' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-63'>3</span><span class='MJXp-mo' id='MJXp-Span-64' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-65'>1</span><span class='MJXp-mo' id='MJXp-Span-66' style='margin-left: 0em; margin-right: 0em;'>}</span></span></span><script type='math/tex' id='MathJax-Element-12'>A = \{1,4,3,4,2,3,1\}</script></var> の場合のあみだくじを以下に示す。くじを引くときは、縦線を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-67'><span class='MJXp-mn' id='MJXp-Span-68'>1</span></span></span><script type='math/tex' id='MathJax-Element-13'>1</script></var> 本選び、その上端から線を下っていく。途中で横線に遭遇したときには必ず曲がらなければならず、また縦線を上向きに辿ってはいけない。たとえばこのあみだくじで左から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-69'><span class='MJXp-mn' id='MJXp-Span-70'>4</span></span></span><script type='math/tex' id='MathJax-Element-14'>4</script></var> 番目の縦線から始めてくじを引くと、左から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-71'><span class='MJXp-mn' id='MJXp-Span-72'>3</span></span></span><script type='math/tex' id='MathJax-Element-15'>3</script></var> 番目の縦線に辿り着く。</p>
#
# <div class='img-nocaption' align='center'>
# <img src='/img/abc/013/4-1.png' width='558px'>
# </div>
#
# <p>さて、ここまでは普通のあみだくじであるが、何かにつけビッグデータという言葉が騒がれる昨今である。あみだくじがこれから先生きのこるためには、あみだくじもビッグになってビッグデータに対抗していかなければならない。</p>
#
# <p>そこで、あみだくじを縦に <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-73'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-74'>D</span></span></span><script type='math/tex' id='MathJax-Element-16'>D</script></var> 個つなげることで巨大なあみだくじを作ることを考えよう。たとえば、先ほど例に挙げたあみだくじを <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-75'><span class='MJXp-mn' id='MJXp-Span-76'>2</span></span></span><script type='math/tex' id='MathJax-Element-17'>2</script></var> 個つなげてみると以下のようになる。この場合、左から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-77'><span class='MJXp-mn' id='MJXp-Span-78'>4</span></span></span><script type='math/tex' id='MathJax-Element-18'>4</script></var> 番目の縦線から始めてくじを引くと、辿り着く場所は左から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-79'><span class='MJXp-mn' id='MJXp-Span-80'>5</span></span></span><script type='math/tex' id='MathJax-Element-19'>5</script></var> 番目の縦線になる。</p>
#
# <div class='img-nocaption' align='center'>
# <img src='/img/abc/013/4-2.png' width='571px'>
# </div>
#
# <p>こうして作った巨大あみだくじだが、あみだくじ本来の目的を果たせなければビッグになった意味もない。つまり、この巨大なあみだくじを使ってくじを引いた結果がどうなるかを効率よく計算できなければ、せっかく作った巨大あみだくじもただの落書きである。</p>
#
# <p>そこで、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-81'><span class='MJXp-mn' id='MJXp-Span-82'>1</span><span class='MJXp-mspace' id='MJXp-Span-83' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-84' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-85' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-86'>k</span><span class='MJXp-mspace' id='MJXp-Span-87' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-88' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-89' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-90'>N</span></span></span><script type='math/tex' id='MathJax-Element-20'>1\,≦\,k\,≦\,N</script></var> を満たすすべての整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-91'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-92'>k</span></span></span><script type='math/tex' id='MathJax-Element-21'>k</script></var> に対し、巨大あみだくじの左から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-93'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-94'>k</span></span></span><script type='math/tex' id='MathJax-Element-22'>k</script></var> 番目の縦線を選んで線を辿っていったとき、最終的に下端で左から何番目の縦線に行き着くかを計算するプログラムを書いて欲しい。</p>
#
# </section>
# </div>
# <hr>
# <div class='io-style'>
# <div class='part'>
#
# <section>
# <h3>入力</h3>
#
# <p>入力は以下の形式で標準入力から与えられる。</p>
#
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-95'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-96'>N</span></span></span><script type='math/tex' id='MathJax-Element-23'>N</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-97'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-98'>M</span></span></span><script type='math/tex' id='MathJax-Element-24'>M</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-99'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-100'>D</span></span></span><script type='math/tex' id='MathJax-Element-25'>D</script></var>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-101'><span class='MJXp-msubsup' id='MJXp-Span-102'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-103' style='margin-right: 0.05em;'>A</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-104' style='vertical-align: -0.4em;'>1</span></span></span></span><script type='math/tex' id='MathJax-Element-26'>A_1</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-105'><span class='MJXp-msubsup' id='MJXp-Span-106'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-107' style='margin-right: 0.05em;'>A</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-108' style='vertical-align: -0.4em;'>2</span></span></span></span><script type='math/tex' id='MathJax-Element-27'>A_2</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-109'><span class='MJXp-mo' id='MJXp-Span-110' style='margin-left: 0em; margin-right: 0.222em;'>.</span><span class='MJXp-mo' id='MJXp-Span-111' style='margin-left: 0em; margin-right: 0.222em;'>.</span><span class='MJXp-mo' id='MJXp-Span-112' style='margin-left: 0em; margin-right: 0.222em;'>.</span></span></span><script type='math/tex' id='MathJax-Element-28'>...</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-113'><span class='MJXp-msubsup' id='MJXp-Span-114'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-115' style='margin-right: 0.05em;'>A</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-116' style='vertical-align: -0.4em;'>M</span></span></span></span><script type='math/tex' id='MathJax-Element-29'>A_M</script></var>
# </pre>
#
# <ul class='simple'>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-117'><span class='MJXp-mn' id='MJXp-Span-118'>1</span></span></span><script type='math/tex' id='MathJax-Element-30'>1</script></var> 行目には、元のあみだくじの縦線の本数を表す整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-119'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-120'>N</span></span></span><script type='math/tex' id='MathJax-Element-31'>N</script></var> (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-121'><span class='MJXp-mn' id='MJXp-Span-122'>2</span><span class='MJXp-mspace' id='MJXp-Span-123' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-124' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-125' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-126'>N</span><span class='MJXp-mspace' id='MJXp-Span-127' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-128' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-129' style='width: 0.167em; height: 0em;'></span><span class='MJXp-msubsup' id='MJXp-Span-130'><span class='MJXp-mn' id='MJXp-Span-131' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-132' style='vertical-align: 0.5em;'>5</span></span></span></span><script type='math/tex' id='MathJax-Element-32'>2\,≦\,N\,≦\,10^5</script></var>)、横線の本数を表す整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-133'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-134'>M</span></span></span><script type='math/tex' id='MathJax-Element-33'>M</script></var> (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-135'><span class='MJXp-mn' id='MJXp-Span-136'>0</span><span class='MJXp-mspace' id='MJXp-Span-137' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-138' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-139' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-140'>M</span><span class='MJXp-mspace' id='MJXp-Span-141' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-142' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-143' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mn' id='MJXp-Span-144'>2</span><span class='MJXp-mo' id='MJXp-Span-145' style='margin-left: 0.267em; margin-right: 0.267em;'>×</span><span class='MJXp-msubsup' id='MJXp-Span-146'><span class='MJXp-mn' id='MJXp-Span-147' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-148' style='vertical-align: 0.5em;'>5</span></span></span></span><script type='math/tex' id='MathJax-Element-34'>0\,≦\,M\,≦\,2 \times 10^5</script></var>)、元のあみだくじを縦につなげる回数を表す整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-149'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-150'>D</span></span></span><script type='math/tex' id='MathJax-Element-35'>D</script></var> (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-151'><span class='MJXp-mn' id='MJXp-Span-152'>1</span><span class='MJXp-mspace' id='MJXp-Span-153' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-154' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-155' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-156'>D</span><span class='MJXp-mspace' id='MJXp-Span-157' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-158' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-159' style='width: 0.167em; height: 0em;'></span><span class='MJXp-msubsup' id='MJXp-Span-160'><span class='MJXp-mn' id='MJXp-Span-161' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-162' style='vertical-align: 0.5em;'>9</span></span></span></span><script type='math/tex' id='MathJax-Element-36'>1\,≦\,D\,≦\,10^9</script></var>) が空白区切りで与えられる。</li>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-163'><span class='MJXp-mn' id='MJXp-Span-164'>2</span></span></span><script type='math/tex' id='MathJax-Element-37'>2</script></var> 行目には、元のあみだくじにおける横線の情報を表す <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-165'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-166'>M</span></span></span><script type='math/tex' id='MathJax-Element-38'>M</script></var> 個の整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-167'><span class='MJXp-msubsup' id='MJXp-Span-168'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-169' style='margin-right: 0.05em;'>A</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-170' style='vertical-align: -0.4em;'>i</span></span></span></span><script type='math/tex' id='MathJax-Element-39'>A_i</script></var> (<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-171'><span class='MJXp-mn' id='MJXp-Span-172'>1</span><span class='MJXp-mspace' id='MJXp-Span-173' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-174' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-175' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-176'>i</span><span class='MJXp-mspace' id='MJXp-Span-177' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-178' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-179' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-180'>M</span></span></span><script type='math/tex' id='MathJax-Element-40'>1\,≦\,i\,≦\,M</script></var>) が空白区切りで与えられる。</li>
#
# </ul>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>部分点</h3>
#
# <p>この問題のテストケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-181'><span class='MJXp-mn' id='MJXp-Span-182'>4</span></span></span><script type='math/tex' id='MathJax-Element-41'>4</script></var> つのグループに分けられており、それぞれに配点が決まっている。</p>
#
# <ul class='simple'>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-183'><span class='MJXp-mn' id='MJXp-Span-184'>1</span></span></span><script type='math/tex' id='MathJax-Element-42'>1</script></var> つめのグループにおいて、テストケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-185'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-186'>D</span><span class='MJXp-mo' id='MJXp-Span-187' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mn' id='MJXp-Span-188'>1</span></span></span><script type='math/tex' id='MathJax-Element-43'>D = 1</script></var> を満たす。このグループのテストケース全てに正解すると <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-189'><span class='MJXp-mn' id='MJXp-Span-190'>10</span></span></span><script type='math/tex' id='MathJax-Element-44'>10</script></var> 点が与えられる。</li>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-191'><span class='MJXp-mn' id='MJXp-Span-192'>2</span></span></span><script type='math/tex' id='MathJax-Element-45'>2</script></var> つめのグループにおいて、テストケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-193'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-194'>N</span><span class='MJXp-mspace' id='MJXp-Span-195' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-196' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-197' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mn' id='MJXp-Span-198'>1</span><span class='MJXp-mo' id='MJXp-Span-199' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-200'>000</span></span></span><script type='math/tex' id='MathJax-Element-46'>N\,≦\,1,000</script></var> および <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-201'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-202'>D</span><span class='MJXp-mspace' id='MJXp-Span-203' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-204' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-205' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mn' id='MJXp-Span-206'>1</span><span class='MJXp-mo' id='MJXp-Span-207' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-208'>000</span></span></span><script type='math/tex' id='MathJax-Element-47'>D\,≦\,1,000</script></var> を満たす。このグループのテストケース全てに正解すると <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-209'><span class='MJXp-mn' id='MJXp-Span-210'>20</span></span></span><script type='math/tex' id='MathJax-Element-48'>20</script></var> 点が与えられる。</li>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-211'><span class='MJXp-mn' id='MJXp-Span-212'>3</span></span></span><script type='math/tex' id='MathJax-Element-49'>3</script></var> つめのグループにおいて、テストケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-213'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-214'>N</span><span class='MJXp-mspace' id='MJXp-Span-215' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mo' id='MJXp-Span-216' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mspace' id='MJXp-Span-217' style='width: 0.167em; height: 0em;'></span><span class='MJXp-mn' id='MJXp-Span-218'>8</span></span></span><script type='math/tex' id='MathJax-Element-50'>N\,≦\,8</script></var> を満たす。このグループのテストケース全てに正解すると <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-219'><span class='MJXp-mn' id='MJXp-Span-220'>20</span></span></span><script type='math/tex' id='MathJax-Element-51'>20</script></var> 点が与えられる。</li>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-221'><span class='MJXp-mn' id='MJXp-Span-222'>4</span></span></span><script type='math/tex' id='MathJax-Element-52'>4</script></var> つめのグループにおいてはテストケースに追加の制限はない。このグループのテストケース全てに正解すると <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-223'><span class='MJXp-mn' id='MJXp-Span-224'>50</span></span></span><script type='math/tex' id='MathJax-Element-53'>50</script></var> 点が与えられる。</li>
#
# </ul>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力</h3>
#
# <p><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-225'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-226'>N</span></span></span><script type='math/tex' id='MathJax-Element-54'>N</script></var> 行出力せよ。このうち <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-227'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-228'>k</span></span></span><script type='math/tex' id='MathJax-Element-55'>k</script></var> 行目には、巨大あみだくじの左から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-229'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-230'>k</span></span></span><script type='math/tex' id='MathJax-Element-56'>k</script></var> 番目の縦線を選んで線を辿っていったとき、下端で左から何番目の縦線に到達するかを表す整数を出力せよ。</p>
#
# <p>出力の末尾にも改行をいれること。</p>
#
# </section>
# </div>
# </div>
# <hr>
# <div class='part'>
#
# <section>
# <h3>入力例1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample0'>5 7 1
# 1 4 3 4 2 3 1
# </pre>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力例1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample1'>4
# 2
# 5
# 3
# 1
# </pre>
#
# <p>この入出力例は問題文中の最初の図で示されたあみだくじに対応している。</p>
#
# </section>
# </div>
# <hr>
# <div class='part'>
#
# <section>
# <h3>入力例2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample2'>5 7 2
# 1 4 3 4 2 3 1
# </pre>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力例2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample3'>3
# 2
# 1
# 5
# 4
# </pre>
#
# <p>この入出力例は問題文中の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-231'><span class='MJXp-mn' id='MJXp-Span-232'>2</span></span></span><script type='math/tex' id='MathJax-Element-57'>2</script></var> 番目の図で示されたあみだくじに対応している。このケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-233'><span class='MJXp-mn' id='MJXp-Span-234'>1</span></span></span><script type='math/tex' id='MathJax-Element-58'>1</script></var> つめのテストグループの制約を満たさないことに注意せよ。</p>
#
# </section>
# </div>
# <hr>
# <div class='part'>
#
# <section>
# <h3>入力例3 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample4' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample4' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample4'>10 20 300
# 9 1 2 5 8 1 9 3 5 6 4 5 4 6 8 3 2 7 9 6
# </pre>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>出力例3 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample5' data-original-title='Copied!'>Copy</span></h3>
#
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample5' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample5'>3
# 7
# 2
# 4
# 5
# 9
# 6
# 1
# 8
# 10
# </pre>
#
# <p>このケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-235'><span class='MJXp-mn' id='MJXp-Span-236'>1</span></span></span><script type='math/tex' id='MathJax-Element-59'>1</script></var> つめおよび <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-237'><span class='MJXp-mn' id='MJXp-Span-238'>3</span></span></span><script type='math/tex' id='MathJax-Element-60'>3</script></var> つめのテストグループの制約を満たさないことに注意せよ。</p>
#
# </section>
# </div>
# </div>
#
# </div>
#
#
#
#
# </div>
# </div>
#
#
#
# <hr>

# %%
from ipywidgets import Textarea
import sys
sys.path.append('../../..')

from utils.multi_line_input import multi_line_input
text_area = Textarea()
input = multi_line_input()

display(text_area)
