# %% [markdown]
# <span class='h2'>A - テレビ</span>
# <hr>
# <p>Time Limit: 2 sec / Memory Limit: 256 MB</p>
#
# <div id='task-statement'>
# <div id='task-statement'>
#
# <div class='part'>
# <section>
# <h3>問題文</h3><p>高橋君は画面の幅が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-2'>W</span></span></span><script type='math/tex' id='MathJax-Element-1'>W</script></var> 、高さが <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-3'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-4'>H</span></span></span><script type='math/tex' id='MathJax-Element-2'>H</script></var> のテレビを持っています。</p>
# <p>このテレビの画面アスペクト比 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-6'>W</span><span class='MJXp-mo' id='MJXp-Span-7' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-8'>H</span></span></span><script type='math/tex' id='MathJax-Element-3'>W:H</script></var> が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-9'><span class='MJXp-mn' id='MJXp-Span-10'>4</span><span class='MJXp-mo' id='MJXp-Span-11' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mn' id='MJXp-Span-12'>3</span></span></span><script type='math/tex' id='MathJax-Element-4'>4:3</script></var> か <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-13'><span class='MJXp-mn' id='MJXp-Span-14'>16</span><span class='MJXp-mo' id='MJXp-Span-15' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mn' id='MJXp-Span-16'>9</span></span></span><script type='math/tex' id='MathJax-Element-5'>16:9</script></var> か判定してください。</p>
# </section>
# </div>
#
# <hr>
#
# <div class='io-style'>
# <div class='part'>
# <section>
# <h3>入力</h3><p>入力は以下の形式で標準入力から与えられる。</p>
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-17'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-18'>W</span></span></span><script type='math/tex' id='MathJax-Element-6'>W</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-19'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-20'>H</span></span></span><script type='math/tex' id='MathJax-Element-7'>H</script></var>
# </pre>
# <ul>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-21'><span class='MJXp-mn' id='MJXp-Span-22'>1</span></span></span><script type='math/tex' id='MathJax-Element-8'>1</script></var> 行目にテレビの画面の幅と高さを表す <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-23'><span class='MJXp-mn' id='MJXp-Span-24'>2</span></span></span><script type='math/tex' id='MathJax-Element-9'>2</script></var> つの整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-25'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-26'>W</span><span class='MJXp-mo' id='MJXp-Span-27' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-28'>H</span><span class='MJXp-mo' id='MJXp-Span-29' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-30'>1</span><span class='MJXp-mo' id='MJXp-Span-31' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-32'>H</span><span class='MJXp-mo' id='MJXp-Span-33' style='margin-left: 0.333em; margin-right: 0.333em;'>&lt;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-34'>W</span><span class='MJXp-mo' id='MJXp-Span-35' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-msubsup' id='MJXp-Span-36'><span class='MJXp-mn' id='MJXp-Span-37' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-38' style='vertical-align: 0.5em;'>5</span></span><span class='MJXp-mo' id='MJXp-Span-39' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-10'>W,H (1≦H<W≦10^5)</script></var> が空白区切りで与えられる。</li>
# <li>テレビの画面アスペクト比は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-40'><span class='MJXp-mn' id='MJXp-Span-41'>4</span><span class='MJXp-mo' id='MJXp-Span-42' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mn' id='MJXp-Span-43'>3</span></span></span><script type='math/tex' id='MathJax-Element-11'>4:3</script></var> か <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-44'><span class='MJXp-mn' id='MJXp-Span-45'>16</span><span class='MJXp-mo' id='MJXp-Span-46' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mn' id='MJXp-Span-47'>9</span></span></span><script type='math/tex' id='MathJax-Element-12'>16:9</script></var> になることが保証される。</li>
# </ul>
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力</h3><p>高橋君のテレビの画面アスペクト比 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-48'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-49'>W</span><span class='MJXp-mo' id='MJXp-Span-50' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-51'>H</span></span></span><script type='math/tex' id='MathJax-Element-13'>W:H</script></var> が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-52'><span class='MJXp-mn' id='MJXp-Span-53'>4</span><span class='MJXp-mo' id='MJXp-Span-54' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mn' id='MJXp-Span-55'>3</span></span></span><script type='math/tex' id='MathJax-Element-14'>4:3</script></var> ならば<code>4:3</code>を、 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-56'><span class='MJXp-mn' id='MJXp-Span-57'>16</span><span class='MJXp-mo' id='MJXp-Span-58' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mn' id='MJXp-Span-59'>9</span></span></span><script type='math/tex' id='MathJax-Element-15'>16:9</script></var> ならば <code>16:9</code> を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-60'><span class='MJXp-mn' id='MJXp-Span-61'>1</span></span></span><script type='math/tex' id='MathJax-Element-16'>1</script></var> 行に出力せよ。改行を忘れないこと。</p>
# </section>
# </div>
# </div>
#
# <hr>
#
# <div class='part'>
# <section>
# <h3>入力例 1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample0'>4 3
# </pre>
#
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力例 1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample1'>4:3
# </pre>
#
# <ul>
# <li>画面の幅が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-62'><span class='MJXp-mn' id='MJXp-Span-63'>4</span></span></span><script type='math/tex' id='MathJax-Element-17'>4</script></var> 、高さが <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-64'><span class='MJXp-mn' id='MJXp-Span-65'>3</span></span></span><script type='math/tex' id='MathJax-Element-18'>3</script></var> のテレビの画面アスペクト比は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-66'><span class='MJXp-mn' id='MJXp-Span-67'>4</span><span class='MJXp-mo' id='MJXp-Span-68' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mn' id='MJXp-Span-69'>3</span></span></span><script type='math/tex' id='MathJax-Element-19'>4:3</script></var> なので<code>4:3</code>と出力してください。</li>
# </ul>
# </section>
# </div>
#
# <hr>
#
# <div class='part'>
# <section>
# <h3>入力例 2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample2'>16 9
# </pre>
#
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力例 2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample3'>16:9
# </pre>
#
# <ul>
# <li>画面の幅が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-70'><span class='MJXp-mn' id='MJXp-Span-71'>16</span></span></span><script type='math/tex' id='MathJax-Element-20'>16</script></var> 、高さが <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-72'><span class='MJXp-mn' id='MJXp-Span-73'>9</span></span></span><script type='math/tex' id='MathJax-Element-21'>9</script></var> のテレビの画面アスペクト比は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-74'><span class='MJXp-mn' id='MJXp-Span-75'>16</span><span class='MJXp-mo' id='MJXp-Span-76' style='margin-left: 0.111em; margin-right: 0.167em;'>:</span><span class='MJXp-mn' id='MJXp-Span-77'>9</span></span></span><script type='math/tex' id='MathJax-Element-22'>16:9</script></var> なので<code>16:9</code>と出力してください。</li>
# </ul>
# </section>
# </div>
#
# <hr>
#
# <div class='part'>
# <section>
# <h3>入力例 3 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample4' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample4' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample4'>28 21
# </pre>
#
# </section>
# </div>
#
# <div class='part'>
# <section>
# <h3>出力例 3 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample5' data-original-title='Copied!'>Copy</span></h3><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample5' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample5'>4:3
# </pre></section>
# </div>
#
# </div>
# </div>
#
#
#
#
# </div>
# </div>
#
#
#
# <hr>
