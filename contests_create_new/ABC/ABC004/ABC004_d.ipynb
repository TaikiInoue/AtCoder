# %% [markdown]
# <span class='h2'>D - マーブル</span>
# <hr>
# <p>Time Limit: 2 sec / Memory Limit: 64 MB</p>
#
# <div id='task-statement'>
# <div class='part'>
#     <h3>問題文</h3>
#     <section>
#         一直線上に無限個の箱が並んでいます。それぞれの箱に、左から右にかけて <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mo' id='MJXp-Span-2' style='margin-left: 0em; margin-right: 0.222em;'>.</span><span class='MJXp-mo' id='MJXp-Span-3' style='margin-left: 0em; margin-right: 0.222em;'>.</span><span class='MJXp-mo' id='MJXp-Span-4' style='margin-left: 0em; margin-right: 0.222em;'>.</span></span></span><script type='math/tex' id='MathJax-Element-1'>...</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mo' id='MJXp-Span-6' style='margin-left: 0em; margin-right: 0.111em;'>−</span><span class='MJXp-mn' id='MJXp-Span-7'>2</span></span></span><script type='math/tex' id='MathJax-Element-2'>-2</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-8'><span class='MJXp-mo' id='MJXp-Span-9' style='margin-left: 0em; margin-right: 0.111em;'>−</span><span class='MJXp-mn' id='MJXp-Span-10'>1</span></span></span><script type='math/tex' id='MathJax-Element-3'>-1</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-11'><span class='MJXp-mn' id='MJXp-Span-12'>0</span></span></span><script type='math/tex' id='MathJax-Element-4'>0</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-13'><span class='MJXp-mn' id='MJXp-Span-14'>1</span></span></span><script type='math/tex' id='MathJax-Element-5'>1</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-15'><span class='MJXp-mn' id='MJXp-Span-16'>2</span></span></span><script type='math/tex' id='MathJax-Element-6'>2</script></var>,<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-17'><span class='MJXp-mo' id='MJXp-Span-18' style='margin-left: 0em; margin-right: 0.222em;'>.</span><span class='MJXp-mo' id='MJXp-Span-19' style='margin-left: 0em; margin-right: 0.222em;'>.</span><span class='MJXp-mo' id='MJXp-Span-20' style='margin-left: 0em; margin-right: 0.222em;'>.</span></span></span><script type='math/tex' id='MathJax-Element-7'>...</script></var> の番号が付いています。<br>
#         いま、番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-21'><span class='MJXp-mo' id='MJXp-Span-22' style='margin-left: 0em; margin-right: 0.111em;'>−</span><span class='MJXp-mn' id='MJXp-Span-23'>100</span></span></span><script type='math/tex' id='MathJax-Element-8'>-100</script></var> の箱に赤いマーブルが <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-24'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-25'>R</span></span></span><script type='math/tex' id='MathJax-Element-9'>R</script></var> 個入っています。同様に、番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-26'><span class='MJXp-mn' id='MJXp-Span-27'>0</span></span></span><script type='math/tex' id='MathJax-Element-10'>0</script></var> の箱に緑のマーブルが <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-28'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-29'>G</span></span></span><script type='math/tex' id='MathJax-Element-11'>G</script></var> 個、番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-30'><span class='MJXp-mn' id='MJXp-Span-31'>100</span></span></span><script type='math/tex' id='MathJax-Element-12'>100</script></var> の箱に青いマーブルが <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-32'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-33'>B</span></span></span><script type='math/tex' id='MathJax-Element-13'>B</script></var> 個入っています。これら以外の箱には何も入っていません。<br>
#         以下の操作を繰り返して、全ての箱に入っているマーブルの個数が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-34'><span class='MJXp-mn' id='MJXp-Span-35'>1</span></span></span><script type='math/tex' id='MathJax-Element-14'>1</script></var> 個以下になるようにして下さい。<br>
#         <ul>
#             <li>マーブルを <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-36'><span class='MJXp-mn' id='MJXp-Span-37'>1</span></span></span><script type='math/tex' id='MathJax-Element-15'>1</script></var> つ選び、それを左右どちらかの隣接する箱に移動させる。</li>
#             <li>ただしこのとき、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-38'><span class='MJXp-mn' id='MJXp-Span-39'>1</span></span></span><script type='math/tex' id='MathJax-Element-16'>1</script></var> つの箱に複数の異なる色のマーブルを入れてはならない。</li>
#         </ul>
#         必要となる最小の操作回数を求めてください。<br>
#     </section>
# </div>
#
# <hr>
#
# <div class='io-style part'>
#     <h3>入力</h3>
#     <section>
#         入力は以下の形式で標準入力から与えられる。
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-40'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-41'>R</span></span></span><script type='math/tex' id='MathJax-Element-17'>R</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-42'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-43'>G</span></span></span><script type='math/tex' id='MathJax-Element-18'>G</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-44'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-45'>B</span></span></span><script type='math/tex' id='MathJax-Element-19'>B</script></var>
# </pre>
#         <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-46'><span class='MJXp-mn' id='MJXp-Span-47'>1</span></span></span><script type='math/tex' id='MathJax-Element-20'>1</script></var> 行目に、マーブルの数を表す整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-48'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-49'>R</span><span class='MJXp-mo' id='MJXp-Span-50' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-51'>G</span><span class='MJXp-mo' id='MJXp-Span-52' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-53'>B</span></span></span><script type='math/tex' id='MathJax-Element-21'>R,G,B</script></var> を半角スペース区切りで与える。
#         <ul>
#             <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-54'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-55'>R</span></span></span><script type='math/tex' id='MathJax-Element-22'>R</script></var> は番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-56'><span class='MJXp-mo' id='MJXp-Span-57' style='margin-left: 0em; margin-right: 0.111em;'>−</span><span class='MJXp-mn' id='MJXp-Span-58'>100</span></span></span><script type='math/tex' id='MathJax-Element-23'>-100</script></var> の箱にある<span style='color: red'>赤い</span>マーブルの数を示す。</li>
#             <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-59'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-60'>G</span></span></span><script type='math/tex' id='MathJax-Element-24'>G</script></var> は番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-61'><span class='MJXp-mn' id='MJXp-Span-62'>0</span></span></span><script type='math/tex' id='MathJax-Element-25'>0</script></var> の箱にある<span style='color: green'>緑の</span>マーブルの数を示す。</li>
#             <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-63'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-64'>B</span></span></span><script type='math/tex' id='MathJax-Element-26'>B</script></var> は番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-65'><span class='MJXp-mn' id='MJXp-Span-66'>100</span></span></span><script type='math/tex' id='MathJax-Element-27'>100</script></var> の箱にある<span style='color: blue'>青い</span>マーブルの数を示す。</li>
#             <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-67'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-68'>R</span><span class='MJXp-mo' id='MJXp-Span-69' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-70'>G</span><span class='MJXp-mo' id='MJXp-Span-71' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-72'>B</span></span></span><script type='math/tex' id='MathJax-Element-28'>R,G,B</script></var> の範囲はそれぞれ、 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-73'><span class='MJXp-mn' id='MJXp-Span-74'>1</span><span class='MJXp-mo' id='MJXp-Span-75' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-76'>R</span><span class='MJXp-mo' id='MJXp-Span-77' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-78'>G</span><span class='MJXp-mo' id='MJXp-Span-79' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-80'>B</span><span class='MJXp-mo' id='MJXp-Span-81' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-82'>300</span></span></span><script type='math/tex' id='MathJax-Element-29'>1≦R,G,B≦300</script></var> である。</li>
#             <ul>
#                 <li>この問題には部分点が設定されている。後述する部分点の項も参照すること。</li>
#             </ul>
#         </ul>
#     </section>
# </div>
#
# <div class='part'>
#     <h3>出力</h3>
#     <section>
#         必要となる最小の操作回数を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-83'><span class='MJXp-mn' id='MJXp-Span-84'>1</span></span></span><script type='math/tex' id='MathJax-Element-30'>1</script></var> 行で出力してください。<br>
#         <span style='color: red'>
# また、出力の末尾には改行を入れること。
# </span>
#     </section>
# </div>
#
# <hr>
#
# <div class='part'>
#     <h3>部分点</h3>
#     <section>
#         <p><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-85'><span class='MJXp-mn' id='MJXp-Span-86'>1</span><span class='MJXp-mo' id='MJXp-Span-87' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-88'>R</span><span class='MJXp-mo' id='MJXp-Span-89' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-90'>G</span><span class='MJXp-mo' id='MJXp-Span-91' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-92'>B</span><span class='MJXp-mo' id='MJXp-Span-93' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-94'>5</span></span></span><script type='math/tex' id='MathJax-Element-31'>1≦R,G,B≦5</script></var>を満たすテストケース全てに正解すると、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-95'><span class='MJXp-mn' id='MJXp-Span-96'>100</span></span></span><script type='math/tex' id='MathJax-Element-32'>100</script></var> 点満点のうち <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-97'><span class='MJXp-mn' id='MJXp-Span-98'>10</span></span></span><script type='math/tex' id='MathJax-Element-33'>10</script></var> 点が与えられる。</p>
#         <p><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-99'><span class='MJXp-mn' id='MJXp-Span-100'>1</span><span class='MJXp-mo' id='MJXp-Span-101' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-102'>R</span><span class='MJXp-mo' id='MJXp-Span-103' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-104'>G</span><span class='MJXp-mo' id='MJXp-Span-105' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-106'>B</span><span class='MJXp-mo' id='MJXp-Span-107' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-108'>40</span></span></span><script type='math/tex' id='MathJax-Element-34'>1≦R,G,B≦40</script></var>を満たすテストケース全てに正解すると、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-109'><span class='MJXp-mn' id='MJXp-Span-110'>100</span></span></span><script type='math/tex' id='MathJax-Element-35'>100</script></var> 点満点のうち <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-111'><span class='MJXp-mn' id='MJXp-Span-112'>30</span></span></span><script type='math/tex' id='MathJax-Element-36'>30</script></var> 点が与えられる。</p>
#     </section>
# </div>
#
# <hr>
#
# <div class='part'>
#     <h3>入力例 1</h3>
#     <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy0' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>2</span><span class='pln'> </span><span class='lit'>3</span><span class='pln'> </span><span class='lit'>4</span></li></ol></pre><pre id='for_copy0' class='source-code-for-copy'>2 3 4
# </pre>
#     </section>
# </div>
#
# <div class='part'>
#     <h3>出力例 1</h3>
#     <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy1' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>7</span></li></ol></pre><pre id='for_copy1' class='source-code-for-copy'>7
# </pre>
#         以下の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-113'><span class='MJXp-mn' id='MJXp-Span-114'>7</span></span></span><script type='math/tex' id='MathJax-Element-37'>7</script></var> 回の移動により、目的を達成することができます。
#             <ul>
#                 <li>番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-115'><span class='MJXp-mo' id='MJXp-Span-116' style='margin-left: 0em; margin-right: 0.111em;'>−</span><span class='MJXp-mn' id='MJXp-Span-117'>100</span></span></span><script type='math/tex' id='MathJax-Element-38'>-100</script></var> の箱に入っている赤いマーブルを左に移動します。</li>
#                 <li>番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-118'><span class='MJXp-mn' id='MJXp-Span-119'>0</span></span></span><script type='math/tex' id='MathJax-Element-39'>0</script></var> の箱に入っている緑のマーブルを左に移動します。</li>
#                 <li>番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-120'><span class='MJXp-mn' id='MJXp-Span-121'>0</span></span></span><script type='math/tex' id='MathJax-Element-40'>0</script></var> の箱に入っている緑のマーブルを右に移動します。</li>
#                 <li>番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-122'><span class='MJXp-mn' id='MJXp-Span-123'>100</span></span></span><script type='math/tex' id='MathJax-Element-41'>100</script></var> の箱に入っている青いマーブルを左に移動します。</li>
#                 <li>番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-124'><span class='MJXp-mn' id='MJXp-Span-125'>99</span></span></span><script type='math/tex' id='MathJax-Element-42'>99</script></var> の箱に入っている青いマーブルを左に移動します。</li>
#                 <li>番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-126'><span class='MJXp-mn' id='MJXp-Span-127'>100</span></span></span><script type='math/tex' id='MathJax-Element-43'>100</script></var> の箱に入っている青いマーブルを左に移動します。</li>
#                 <li>番号が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-128'><span class='MJXp-mn' id='MJXp-Span-129'>100</span></span></span><script type='math/tex' id='MathJax-Element-44'>100</script></var> の箱に入っている青いマーブルを右に移動します。</li>
#             </ul>
#         これは、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-130'><span class='MJXp-mn' id='MJXp-Span-131'>10</span></span></span><script type='math/tex' id='MathJax-Element-45'>10</script></var> 点分の部分点に含まれる入力になります。
#     </section>
# </div>
#
# <hr>
#
# <div class='part'>
#     <h3>入力例 2</h3>
#     <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy2' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>17</span><span class='pln'> </span><span class='lit'>2</span><span class='pln'> </span><span class='lit'>34</span></li></ol></pre><pre id='for_copy2' class='source-code-for-copy'>17 2 34
# </pre>
#     </section>
# </div>
#
# <div class='part'>
#     <h3>出力例 2</h3>
#     <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy3' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>362</span></li></ol></pre><pre id='for_copy3' class='source-code-for-copy'>362
# </pre>
#         <ul>
#             <li>これは、 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-132'><span class='MJXp-mn' id='MJXp-Span-133'>30</span></span></span><script type='math/tex' id='MathJax-Element-46'>30</script></var> 点分の部分点に含まれる入力になります。</li>
#         </ul>
#     </section>
# </div>
#
# <hr>
#
# <div class='part'>
#     <h3>入力例 3</h3>
#     <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy4' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>267</span><span class='pln'> </span><span class='lit'>294</span><span class='pln'> </span><span class='lit'>165</span></li></ol></pre><pre id='for_copy4' class='source-code-for-copy'>267 294 165
# </pre>
#     </section>
# </div>
#
# <div class='part'>
#     <h3>出力例 3</h3>
#     <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy5' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>88577</span></li></ol></pre><pre id='for_copy5' class='source-code-for-copy'>88577
# </pre>
#         <ul>
#         </ul>
#     </section>
# </div>
# </div>
#
#
#
#
# </div>
# </div>
#
#
#
# <hr>

# %%
from ipywidgets import Textarea
import sys
sys.path.append('../../..')

from utils.multi_line_input import multi_line_input
text_area = Textarea()
input = multi_line_input()

display(text_area)
