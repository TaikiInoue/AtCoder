# %% [markdown]
# <span class='h2'>B - ペア</span>
# <hr>
# <p>Time Limit: 2 sec / Memory Limit: 256 MB</p>
#
# <div id='task-statement'>
# <span class='lang'><span class='lang-ja' style='display: inline;'>
#
# <section>
# <h3>問題文</h3>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-msubsup' id='MJXp-Span-2'><span class='MJXp-mn' id='MJXp-Span-3' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-4' style='vertical-align: 0.5em;'>9</span></span></span></span><span id='MathJax-Element-1-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-1' class='mjx-math'><span id='MJXc-Node-2' class='mjx-mrow'><span id='MJXc-Node-3' class='mjx-msubsup'><span class='mjx-base'><span id='MJXc-Node-4' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.387em;'>10</span></span></span><span class='mjx-sup' style='font-size: 70.7%; vertical-align: 0.591em; padding-left: 0px; padding-right: 0.071em;'><span id='MJXc-Node-5' class='mjx-mn' style=''><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.387em;'>9</span></span></span></span></span></span></span><script type='math/tex' id='MathJax-Element-1'>10^9</script></var> 人の人がいます。人には <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mn' id='MJXp-Span-6'>1</span></span></span><span id='MathJax-Element-2-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-6' class='mjx-math'><span id='MJXc-Node-7' class='mjx-mrow'><span id='MJXc-Node-8' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.332em;'>1</span></span></span></span></span><script type='math/tex' id='MathJax-Element-2'>1</script></var> から <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-7'><span class='MJXp-msubsup' id='MJXp-Span-8'><span class='MJXp-mn' id='MJXp-Span-9' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-10' style='vertical-align: 0.5em;'>9</span></span></span></span><span id='MathJax-Element-3-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-9' class='mjx-math'><span id='MJXc-Node-10' class='mjx-mrow'><span id='MJXc-Node-11' class='mjx-msubsup'><span class='mjx-base'><span id='MJXc-Node-12' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.387em;'>10</span></span></span><span class='mjx-sup' style='font-size: 70.7%; vertical-align: 0.591em; padding-left: 0px; padding-right: 0.071em;'><span id='MJXc-Node-13' class='mjx-mn' style=''><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.387em;'>9</span></span></span></span></span></span></span><script type='math/tex' id='MathJax-Element-3'>10^9</script></var> までの番号がついています。
# <br><br>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-11'><span class='MJXp-mn' id='MJXp-Span-12'>1</span></span></span><span id='MathJax-Element-4-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-14' class='mjx-math'><span id='MJXc-Node-15' class='mjx-mrow'><span id='MJXc-Node-16' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.332em;'>1</span></span></span></span></span><script type='math/tex' id='MathJax-Element-4'>1</script></var> 番と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-13'><span class='MJXp-mn' id='MJXp-Span-14'>2</span></span></span><span id='MathJax-Element-5-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-17' class='mjx-math'><span id='MJXc-Node-18' class='mjx-mrow'><span id='MJXc-Node-19' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.332em;'>2</span></span></span></span></span><script type='math/tex' id='MathJax-Element-5'>2</script></var> 番の人、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-15'><span class='MJXp-mn' id='MJXp-Span-16'>3</span></span></span><span id='MathJax-Element-6-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-20' class='mjx-math'><span id='MJXc-Node-21' class='mjx-mrow'><span id='MJXc-Node-22' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.387em;'>3</span></span></span></span></span><script type='math/tex' id='MathJax-Element-6'>3</script></var> 番と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-17'><span class='MJXp-mn' id='MJXp-Span-18'>4</span></span></span><span id='MathJax-Element-7-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-23' class='mjx-math'><span id='MJXc-Node-24' class='mjx-mrow'><span id='MJXc-Node-25' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.332em;'>4</span></span></span></span></span><script type='math/tex' id='MathJax-Element-7'>4</script></var> 番の人、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-19'><span class='MJXp-mn' id='MJXp-Span-20'>5</span></span></span><span id='MathJax-Element-8-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-26' class='mjx-math'><span id='MJXc-Node-27' class='mjx-mrow'><span id='MJXc-Node-28' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.387em;'>5</span></span></span></span></span><script type='math/tex' id='MathJax-Element-8'>5</script></var> 番と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-21'><span class='MJXp-mn' id='MJXp-Span-22'>6</span></span></span><span id='MathJax-Element-9-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-29' class='mjx-math'><span id='MJXc-Node-30' class='mjx-mrow'><span id='MJXc-Node-31' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.387em;'>6</span></span></span></span></span><script type='math/tex' id='MathJax-Element-9'>6</script></var> 番の人、…　がペアになりました。
# <br><br>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-23'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-24'>n</span></span></span><span id='MathJax-Element-10-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-32' class='mjx-math'><span id='MJXc-Node-33' class='mjx-mrow'><span id='MJXc-Node-34' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.222em; padding-bottom: 0.277em;'>n</span></span></span></span></span><script type='math/tex' id='MathJax-Element-10'>n</script></var> 番の人とペアになった人の番号を求めてください。
# </section>
#
# <hr>
#
# <div class='io-style'>
#
# <section>
# <h3>入力</h3>
# <p>入力は以下の形式で標準入力から与えられる。</p>
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-25'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-26'>n</span></span></span><span id='MathJax-Element-11-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 110%;'><span id='MJXc-Node-35' class='mjx-math'><span id='MJXc-Node-36' class='mjx-mrow'><span id='MJXc-Node-37' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.23em; padding-bottom: 0.287em;'>n</span></span></span></span></span><script type='math/tex' id='MathJax-Element-11'>n</script></var>
# </pre>
# <ul>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-27'><span class='MJXp-mn' id='MJXp-Span-28'>1</span><span class='MJXp-mo' id='MJXp-Span-29' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-30'>n</span><span class='MJXp-mo' id='MJXp-Span-31' style='margin-left: 0.333em; margin-right: 0.333em;'>≤</span><span class='MJXp-msubsup' id='MJXp-Span-32'><span class='MJXp-mn' id='MJXp-Span-33' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-34' style='vertical-align: 0.5em;'>9</span></span></span></span><span id='MathJax-Element-12-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-38' class='mjx-math'><span id='MJXc-Node-39' class='mjx-mrow'><span id='MJXc-Node-40' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.332em;'>1</span></span><span id='MJXc-Node-41' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.332em; padding-bottom: 0.496em;'>≤</span></span><span id='MJXc-Node-42' class='mjx-mi MJXc-space3'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.222em; padding-bottom: 0.277em;'>n</span></span><span id='MJXc-Node-43' class='mjx-mo MJXc-space3'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.332em; padding-bottom: 0.496em;'>≤</span></span><span id='MJXc-Node-44' class='mjx-msubsup MJXc-space3'><span class='mjx-base'><span id='MJXc-Node-45' class='mjx-mn'><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.387em;'>10</span></span></span><span class='mjx-sup' style='font-size: 70.7%; vertical-align: 0.591em; padding-left: 0px; padding-right: 0.071em;'><span id='MJXc-Node-46' class='mjx-mn' style=''><span class='mjx-char MJXc-TeX-main-R' style='padding-top: 0.387em; padding-bottom: 0.387em;'>9</span></span></span></span></span></span></span><script type='math/tex' id='MathJax-Element-12'>1 ≤ n ≤ 10^9</script></var> をみたす。</li>
# </ul>
# </section>
#
# <section>
# <h3>出力</h3>
# <p><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-35'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-36'>n</span></span></span><span id='MathJax-Element-13-Frame' class='mjx-chtml MathJax_CHTML MJXc-processed' tabindex='0' style='display: none;' style='font-size: 114%;'><span id='MJXc-Node-47' class='mjx-math'><span id='MJXc-Node-48' class='mjx-mrow'><span id='MJXc-Node-49' class='mjx-mi'><span class='mjx-char MJXc-TeX-math-I' style='padding-top: 0.222em; padding-bottom: 0.277em;'>n</span></span></span></span></span><script type='math/tex' id='MathJax-Element-13'>n</script></var> 番の人とペアになった人の番号を出力せよ。
# 出力の末尾には改行を入れること。</p>
# </section>
#
# </div>
#
#
#
# <hr>
#
# <section>
# <h3>入力例1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></h3>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample0' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample0'>100
# </pre>
# </section>
#
# <section>
# <h3>出力例1 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></h3>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample1' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample1'>99
# </pre>
# </section>
#
# <hr>
#
# <section>
# <h3>入力例2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></h3>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample2' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample2'>123456789
# </pre>
# </section>
#
# <section>
# <h3>出力例2 <span class='btn btn-default btn-sm btn-copy' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></h3>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='pre-sample3' data-original-title='Copied!'>Copy</span></div><pre id='pre-sample3'>123456790
# </pre>
# </section>
#
#
#
# </span>
#
# </span></div>
#
#
#
#
# </div>
# </div>
#
#
#
# <hr>
