# %% [markdown]
# <span class='h2'>D - 高橋くんと木の直径</span>
# <hr>
# <p>Time Limit: 2 sec / Memory Limit: 256 MB</p>
#
# <div id='task-statement'>
# <div id='task-statement'>
# <div class='part'>
#
# <section>
# <h3>問題文</h3>
#
# <p>高橋くんは木の直径を求めるのに夢中です。
# 木とは、頂点とそれを結ぶ辺からなる構造「グラフ」の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mn' id='MJXp-Span-2'>1</span></span></span><script type='math/tex' id='MathJax-Element-1'>1</script></var> 種で、頂点の数を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-3'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-4'>N</span></span></span><script type='math/tex' id='MathJax-Element-2'>N</script></var> 個とすると、辺は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-6'>N</span><span class='MJXp-mo' id='MJXp-Span-7' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mn' id='MJXp-Span-8'>1</span></span></span><script type='math/tex' id='MathJax-Element-3'>N-1</script></var> 本あり、どの頂点も他の全ての頂点に辺で間接・直接的につながっています。</p>
#
# <p></p><div class='img-nocaption' align='center'>
# <img src='/img/abc/019/tree.png'>
# </div><p></p>
#
# <p>この問題では、辺には整数の重みがついています。2頂点の間の距離を、その2つの頂点をつなぐ辺の重みの和と定義します。</p>
#
# <p>木の直径とは、最も離れた2つの頂点の間の距離です。</p>
#
# <p>以下のような木を考えてみましょう。辺の側に書かれた数が、その辺の重みです。</p>
#
# <p></p><div class='img-nocaption' align='center'>
# <img src='/img/abc/019/tree_with_weight.png'>
# </div><p></p>
#
# <p>この場合、頂点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-9'><span class='MJXp-mn' id='MJXp-Span-10'>1</span></span></span><script type='math/tex' id='MathJax-Element-4'>1</script></var> と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-11'><span class='MJXp-mn' id='MJXp-Span-12'>2</span></span></span><script type='math/tex' id='MathJax-Element-5'>2</script></var> の距離は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-13'><span class='MJXp-mn' id='MJXp-Span-14'>1</span></span></span><script type='math/tex' id='MathJax-Element-6'>1</script></var>、頂点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-15'><span class='MJXp-mn' id='MJXp-Span-16'>2</span></span></span><script type='math/tex' id='MathJax-Element-7'>2</script></var> と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-17'><span class='MJXp-mn' id='MJXp-Span-18'>4</span></span></span><script type='math/tex' id='MathJax-Element-8'>4</script></var> の間の距離は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-19'><span class='MJXp-mn' id='MJXp-Span-20'>1</span><span class='MJXp-mo' id='MJXp-Span-21' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-22'>2</span><span class='MJXp-mo' id='MJXp-Span-23' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mn' id='MJXp-Span-24'>3</span></span></span><script type='math/tex' id='MathJax-Element-9'>1+2=3</script></var> となります。頂点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-25'><span class='MJXp-mn' id='MJXp-Span-26'>3</span></span></span><script type='math/tex' id='MathJax-Element-10'>3</script></var> と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-27'><span class='MJXp-mn' id='MJXp-Span-28'>5</span></span></span><script type='math/tex' id='MathJax-Element-11'>5</script></var> の間の距離は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-29'><span class='MJXp-mn' id='MJXp-Span-30'>3</span><span class='MJXp-mo' id='MJXp-Span-31' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-32'>4</span><span class='MJXp-mo' id='MJXp-Span-33' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mn' id='MJXp-Span-34'>7</span></span></span><script type='math/tex' id='MathJax-Element-12'>3+4=7</script></var>、頂点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-35'><span class='MJXp-mn' id='MJXp-Span-36'>4</span></span></span><script type='math/tex' id='MathJax-Element-13'>4</script></var> と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-37'><span class='MJXp-mn' id='MJXp-Span-38'>5</span></span></span><script type='math/tex' id='MathJax-Element-14'>5</script></var> の間の距離も <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-39'><span class='MJXp-mn' id='MJXp-Span-40'>2</span><span class='MJXp-mo' id='MJXp-Span-41' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-42'>1</span><span class='MJXp-mo' id='MJXp-Span-43' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-44'>4</span><span class='MJXp-mo' id='MJXp-Span-45' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mn' id='MJXp-Span-46'>7</span></span></span><script type='math/tex' id='MathJax-Element-15'>2+1+4=7</script></var> で、この距離がこの木の頂点の間では最大なので、木の直径は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-47'><span class='MJXp-mn' id='MJXp-Span-48'>7</span></span></span><script type='math/tex' id='MathJax-Element-16'>7</script></var> となります。</p>
#
# <p>高橋くんは、頂点の数と <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-49'><span class='MJXp-mn' id='MJXp-Span-50'>2</span></span></span><script type='math/tex' id='MathJax-Element-17'>2</script></var> 頂点間の距離の情報から、木の直径を求めることに興味が出てきました。
# この問題では、あなたは木の頂点の数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-51'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-52'>N</span></span></span><script type='math/tex' id='MathJax-Element-18'>N</script></var> を最初に与えられ、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-53'><span class='MJXp-mn' id='MJXp-Span-54'>2</span></span></span><script type='math/tex' id='MathJax-Element-19'>2</script></var> 頂点の間の距離を尋ねる質問を何回か行い、木の直径を求めます。</p>
#
# <p>ただし、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-55'><span class='MJXp-mn' id='MJXp-Span-56'>2</span></span></span><script type='math/tex' id='MathJax-Element-20'>2</script></var> 頂点間の距離を聞く回数には制限があります。</p>
#
# <p>制限された質問の回数以内で木の直径を求めるプログラムを書いてください。</p>
#
# </section>
# </div>
# <hr>
# <div class='io-style'>
# <div class='part'>
#
# <section>
# <h3>入出力</h3>
#
# <p>まず，木の頂点の数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-57'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-58'>N</span></span></span><script type='math/tex' id='MathJax-Element-21'>N</script></var> が標準入力に与えられる。</p>
#
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-59'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-60'>N</span></span></span><script type='math/tex' id='MathJax-Element-22'>N</script></var>
# </pre>
#
# <p>続いて，あなたのプログラムは何回か応答プログラムに質問をする．質問のフォーマットは以下のとおりである。</p>
#
# <pre>? <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-61'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-62'>a</span></span></span><script type='math/tex' id='MathJax-Element-23'>a</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-63'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-64'>b</span></span></span><script type='math/tex' id='MathJax-Element-24'>b</script></var>
# </pre>
#
# <p>この質問で，<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-65'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-66'>a</span><span class='MJXp-mo' id='MJXp-Span-67' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-68'>b</span></span></span><script type='math/tex' id='MathJax-Element-25'>a,b</script></var> 間の距離が標準入力に1行で渡される。<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-69'><span class='MJXp-mn' id='MJXp-Span-70'>1</span><span class='MJXp-mo' id='MJXp-Span-71' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-72'>a</span><span class='MJXp-mo' id='MJXp-Span-73' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-74'>b</span><span class='MJXp-mo' id='MJXp-Span-75' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-76'>N</span></span></span><script type='math/tex' id='MathJax-Element-26'>1 ≦ a, b ≦ N</script></var> かつ <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-77'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-78'>a</span><span class='MJXp-mo' id='MJXp-Span-79' style='margin-left: 0.333em; margin-right: 0.333em;'>≠</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-80'>b</span></span></span><script type='math/tex' id='MathJax-Element-27'>a≠b</script></var> を満たしていなければならない。</p>
#
# <p>何回か質問を行った後、あなたは木の直径を当てる。木の直径を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-81'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-82'>d</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-83'>i</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-84'>a</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-85'>m</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-86'>e</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-87'>t</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-88'>e</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-89'>r</span></span></span><script type='math/tex' id='MathJax-Element-28'>diameter</script></var> とおくと、</p>
#
# <pre>! <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-90'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-91'>d</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-92'>i</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-93'>a</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-94'>m</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-95'>e</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-96'>t</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-97'>e</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-98'>r</span></span></span><script type='math/tex' id='MathJax-Element-29'>diameter</script></var>
# </pre>
#
# <p>というフォーマットで出力する。木の直径を出力した後、あなたのプログラムは直ちに終了しなければならない。終了しなかった場合のジャッジ結果は不定である。</p>
#
# <p>また、これら以外のフォーマットで出力した場合のジャッジ結果も不定である。</p>
#
# <p>この問題ではテストケースごとに質問回数の上限値が設定されており、プログラムの行った質問の回数がその上限値を上回ると誤答と判定される。</p>
#
# <p>正答かどうかは木の直径の出力で判断される。木の直径を特定し得ない質問しかしていない場合でも、直径が正しければ正答となる。</p>
#
# <hr>
#
# <p>頂点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-99'><span class='MJXp-mn' id='MJXp-Span-100'>1</span></span></span><script type='math/tex' id='MathJax-Element-30'>1</script></var> と頂点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-101'><span class='MJXp-mn' id='MJXp-Span-102'>2</span></span></span><script type='math/tex' id='MathJax-Element-31'>2</script></var> の間の距離を質問し、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-103'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-104'>d</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-105'>i</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-106'>s</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-107'>t</span></span></span><script type='math/tex' id='MathJax-Element-32'>dist</script></var> という変数で結果を受け取る例をいくつかの言語について示す。</p>
#
# <p>ただし、ここに書かれている方法以外で入出力を行っても良い。</p>
#
# <p><span style='color: red'>出力した後に、出力をflushしなければならないことに注意せよ。flushしなかった場合、TLEとなることがある。</span></p>
#
#
# <p>C
# </p><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy0' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='font-size: 12px; letter-spacing: 0px;'><ol class='linenums'><li class='L0'><span class='pln'>printf</span><span class='pun'>(</span><span class='str'>'? %d %d\n'</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>1</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>2</span><span class='pun'>);</span></li><li class='L1'><span class='pln'>fflush</span><span class='pun'>(</span><span class='pln'>stdout</span><span class='pun'>);</span></li><li class='L2'><span class='pln'>scanf</span><span class='pun'>(</span><span class='str'>'%d'</span><span class='pun'>,</span><span class='pln'> </span><span class='pun'>&amp;</span><span class='pln'>dist</span><span class='pun'>);</span></li></ol></pre><pre id='for_copy0' class='source-code-for-copy'>printf('? %d %d\n', 1, 2);
# fflush(stdout);
# scanf('%d', &amp;dist);
# </pre><p></p>
#
# <p>C++
# </p><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy1' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='font-size: 12px; letter-spacing: 0px;'><ol class='linenums'><li class='L0'><span class='pln'>cout </span><span class='pun'>&lt;&lt;</span><span class='pln'> </span><span class='str'>'? '</span><span class='pln'> </span><span class='pun'>&lt;&lt;</span><span class='pln'> </span><span class='lit'>1</span><span class='pln'> </span><span class='pun'>&lt;&lt;</span><span class='pln'> </span><span class='str'>' '</span><span class='pln'> </span><span class='pun'>&lt;&lt;</span><span class='pln'> </span><span class='lit'>2</span><span class='pln'> </span><span class='pun'>&lt;&lt;</span><span class='pln'> endl</span><span class='pun'>;</span></li><li class='L1'><span class='pln'>cin </span><span class='pun'>&gt;&gt;</span><span class='pln'> dist</span><span class='pun'>;</span></li></ol></pre><pre id='for_copy1' class='source-code-for-copy'>cout &lt;&lt; '? ' &lt;&lt; 1 &lt;&lt; ' ' &lt;&lt; 2 &lt;&lt; endl;
# cin &gt;&gt; dist;
# </pre><p></p>
#
# <p>Java
# </p><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy2' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='font-size: 12px; letter-spacing: 0px;'><ol class='linenums'><li class='L0'><span class='typ'>System</span><span class='pun'>.</span><span class='kwd'>out</span><span class='pun'>.</span><span class='pln'>printf</span><span class='pun'>(</span><span class='str'>'? %d %d\n'</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>1</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>2</span><span class='pun'>);</span></li><li class='L1'><span class='typ'>Scanner</span><span class='pln'> scanner </span><span class='pun'>=</span><span class='pln'> </span><span class='kwd'>new</span><span class='pln'> </span><span class='typ'>Scanner</span><span class='pun'>(</span><span class='typ'>System</span><span class='pun'>.</span><span class='kwd'>in</span><span class='pun'>);</span></li><li class='L2'><span class='pln'>dist </span><span class='pun'>=</span><span class='pln'> scanner</span><span class='pun'>.</span><span class='pln'>nextInt</span><span class='pun'>();</span></li></ol></pre><pre id='for_copy2' class='source-code-for-copy'>System.out.printf('? %d %d\n', 1, 2);
# Scanner scanner = new Scanner(System.in);
# dist = scanner.nextInt();
# </pre><p></p>
#
# <p>C#
# </p><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy3' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='font-size: 12px; letter-spacing: 0px;'><ol class='linenums'><li class='L0'><span class='typ'>Console</span><span class='pun'>.</span><span class='typ'>WriteLine</span><span class='pun'>(</span><span class='str'>'? {0} {1}'</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>1</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>2</span><span class='pun'>);</span></li><li class='L1'><span class='pln'>dist </span><span class='pun'>=</span><span class='pln'> </span><span class='kwd'>int</span><span class='pun'>.</span><span class='typ'>Parse</span><span class='pun'>(</span><span class='typ'>Console</span><span class='pun'>.</span><span class='typ'>ReadLine</span><span class='pun'>());</span></li></ol></pre><pre id='for_copy3' class='source-code-for-copy'>Console.WriteLine('? {0} {1}', 1, 2);
# dist = int.Parse(Console.ReadLine());
# </pre><p></p>
#
# <p>D
# </p><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy4' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='font-size: 12px; letter-spacing: 0px;'><ol class='linenums'><li class='L0'><span class='pln'>writeln</span><span class='pun'>(</span><span class='str'>'? '</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>1</span><span class='pun'>,</span><span class='pln'> </span><span class='str'>' '</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>2</span><span class='pun'>);</span></li><li class='L1'><span class='pln'>stdout</span><span class='pun'>.</span><span class='pln'>flush</span><span class='pun'>();</span></li><li class='L2'><span class='pln'>dist </span><span class='pun'>=</span><span class='pln'> readln</span><span class='pun'>.</span><span class='pln'>chomp</span><span class='pun'>.</span><span class='pln'>to</span><span class='pun'>!</span><span class='kwd'>int</span><span class='pun'>;</span></li></ol></pre><pre id='for_copy4' class='source-code-for-copy'>writeln('? ', 1, ' ', 2);
# stdout.flush();
# dist = readln.chomp.to!int;
# </pre><p></p>
#
# <p>PHP
# </p><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy5' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='font-size: 12px; letter-spacing: 0px;'><ol class='linenums'><li class='L0'><span class='pln'>echo </span><span class='str'>'? '</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>1</span><span class='pun'>,</span><span class='pln'> </span><span class='str'>' '</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>2</span><span class='pun'>,</span><span class='pln'> PHP_EOL</span><span class='pun'>;</span></li><li class='L1'><span class='pln'>$dist </span><span class='pun'>=</span><span class='pln'> trim</span><span class='pun'>(</span><span class='pln'>fgets</span><span class='pun'>(</span><span class='pln'>STDIN</span><span class='pun'>));</span></li></ol></pre><pre id='for_copy5' class='source-code-for-copy'>echo '? ', 1, ' ', 2, PHP_EOL;
# $dist = trim(fgets(STDIN));
# </pre><p></p>
#
# <p>Python
# </p><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy6' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='font-size: 12px; letter-spacing: 0px;'><ol class='linenums'><li class='L0'><span class='kwd'>print</span><span class='pln'> </span><span class='str'>'? {0} {1}'</span><span class='pun'>.</span><span class='pln'>format</span><span class='pun'>(</span><span class='lit'>1</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>2</span><span class='pun'>)</span></li><li class='L1'><span class='pln'>sys</span><span class='pun'>.</span><span class='pln'>stdout</span><span class='pun'>.</span><span class='pln'>flush</span><span class='pun'>()</span></li><li class='L2'><span class='pln'>dist </span><span class='pun'>=</span><span class='pln'> </span><span class='kwd'>int</span><span class='pun'>(</span><span class='pln'>raw_input</span><span class='pun'>())</span></li></ol></pre><pre id='for_copy6' class='source-code-for-copy'>print '? {0} {1}'.format(1, 2)
# sys.stdout.flush()
# dist = int(raw_input())
# </pre><p></p>
#
# <p>Perl
# </p><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy7' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='font-size: 12px; letter-spacing: 0px;'><ol class='linenums'><li class='L0'><span class='pln'>$</span><span class='pun'>|=</span><span class='lit'>1</span><span class='pun'>;</span></li><li class='L1'><span class='kwd'>print</span><span class='pln'> </span><span class='str'>'? '</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>1</span><span class='pun'>,</span><span class='pln'> </span><span class='str'>' '</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>2</span><span class='pun'>,</span><span class='pln'> </span><span class='str'>'\n'</span><span class='pun'>;</span></li><li class='L2'><span class='pln'>$dist </span><span class='pun'>=</span><span class='pln'> </span><span class='pun'>&lt;&gt;;</span></li></ol></pre><pre id='for_copy7' class='source-code-for-copy'>$|=1;
# print '? ', 1, ' ', 2, '\n';
# $dist = &lt;&gt;;
# </pre><p></p>
#
# <p>Ruby
# </p><div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy8' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='font-size: 12px; letter-spacing: 0px;'><ol class='linenums'><li class='L0'><span class='kwd'>print</span><span class='pln'> </span><span class='str'>'? '</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>1</span><span class='pun'>,</span><span class='pln'> </span><span class='str'>' '</span><span class='pun'>,</span><span class='pln'> </span><span class='lit'>2</span><span class='pun'>,</span><span class='pln'> </span><span class='str'>'\n'</span></li><li class='L1'><span class='pln'>STDOUT</span><span class='pun'>.</span><span class='pln'>flush</span></li><li class='L2'><span class='pln'>dist </span><span class='pun'>=</span><span class='pln'> gets</span><span class='pun'>.</span><span class='pln'>to_i</span></li></ol></pre><pre id='for_copy8' class='source-code-for-copy'>print '? ', 1, ' ', 2, '\n'
# STDOUT.flush
# dist = gets.to_i
# </pre><p></p>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>制約</h3>
#
# <ul class='simple'>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-108'><span class='MJXp-mn' id='MJXp-Span-109'>2</span><span class='MJXp-mo' id='MJXp-Span-110' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-111'>N</span><span class='MJXp-mo' id='MJXp-Span-112' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-113'>50</span></span></span><script type='math/tex' id='MathJax-Element-33'>2 ≦ N ≦ 50</script></var></li>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-114'><span class='MJXp-mn' id='MJXp-Span-115'>1</span><span class='MJXp-mo' id='MJXp-Span-116' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mo' id='MJXp-Span-117' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mrow' id='MJXp-Span-118'><span class='MJXp-mo' id='MJXp-Span-119' style='margin-left: 0.278em; margin-right: 0.278em;'>そ</span></span><span class='MJXp-mrow' id='MJXp-Span-120'><span class='MJXp-mo' id='MJXp-Span-121' style='margin-left: 0.278em; margin-right: 0.278em;'>れ</span></span><span class='MJXp-mrow' id='MJXp-Span-122'><span class='MJXp-mo' id='MJXp-Span-123' style='margin-left: 0.278em; margin-right: 0.278em;'>ぞ</span></span><span class='MJXp-mrow' id='MJXp-Span-124'><span class='MJXp-mo' id='MJXp-Span-125' style='margin-left: 0.278em; margin-right: 0.278em;'>れ</span></span><span class='MJXp-mrow' id='MJXp-Span-126'><span class='MJXp-mo' id='MJXp-Span-127' style='margin-left: 0.278em; margin-right: 0.278em;'>の</span></span><span class='MJXp-mrow' id='MJXp-Span-128'><span class='MJXp-mo' id='MJXp-Span-129' style='margin-left: 0.278em; margin-right: 0.278em;'>辺</span></span><span class='MJXp-mrow' id='MJXp-Span-130'><span class='MJXp-mo' id='MJXp-Span-131' style='margin-left: 0.278em; margin-right: 0.278em;'>の</span></span><span class='MJXp-mrow' id='MJXp-Span-132'><span class='MJXp-mo' id='MJXp-Span-133' style='margin-left: 0.278em; margin-right: 0.278em;'>重</span></span><span class='MJXp-mrow' id='MJXp-Span-134'><span class='MJXp-mo' id='MJXp-Span-135' style='margin-left: 0.278em; margin-right: 0.278em;'>み</span></span><span class='MJXp-mo' id='MJXp-Span-136' style='margin-left: 0em; margin-right: 0em;'>)</span><span class='MJXp-mo' id='MJXp-Span-137' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-msubsup' id='MJXp-Span-138'><span class='MJXp-mn' id='MJXp-Span-139' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-140' style='vertical-align: 0.5em;'>6</span></span></span></span><script type='math/tex' id='MathJax-Element-34'>1 ≦ (それぞれの辺の重み) ≦ 10^6</script></var></li>
#
# </ul>
#
# </section>
# </div>
# </div>
# <hr>
# <div class='part'>
#
# <section>
# <h3>部分点</h3>
#
# <p>この問題には部分点が設定されている。</p>
#
# <ul class='simple'>
#
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-141'><span class='MJXp-mn' id='MJXp-Span-142'>20</span></span></span><script type='math/tex' id='MathJax-Element-35'>20</script></var> 点分のテストケースにおいて、質問回数の上限値は 1300 回である。</li>
#
# <li>別の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-143'><span class='MJXp-mn' id='MJXp-Span-144'>80</span></span></span><script type='math/tex' id='MathJax-Element-36'>80</script></var> 点分のテストケースにおいて、質問回数の上限値は 100 回である。</li>
#
# </ul>
#
# </section>
# </div>
# <div class='part'>
#
# <section>
# <h3>入出力例</h3>
#
# <p>木が以下のような形状のとき、</p>
#
# <p></p><div class='img-nocaption' align='center'>
# <img src='/img/abc/019/sample1.png'>
# </div><p></p>
#
# <p>以下のような入出力が考えられる。</p>
#
# <table border='1' class='docutils'>
#
# <colgroup>
#
# <col width='50%'>
#
# <col width='50%'>
#
# </colgroup>
#
# <thead valign='bottom'>
#
# <tr>
# <th class='head'>プログラムへの入力</th>
#
# <th class='head'>プログラムの出力</th>
#
# </tr>
#
# </thead>
#
# <tbody valign='top'>
#
# <tr>
# <td>5</td>
#
# <td> </td>
#
# </tr>
#
# <tr>
# <td> </td>
#
# <td>? 1 2</td>
#
# </tr>
#
# <tr>
# <td>5</td>
#
# <td> </td>
#
# </tr>
#
# <tr>
# <td> </td>
#
# <td>? 2 4</td>
#
# </tr>
#
# <tr>
# <td>1</td>
#
# <td> </td>
#
# </tr>
#
# <tr>
# <td> </td>
#
# <td>? 4 5</td>
#
# </tr>
#
# <tr>
# <td>2</td>
#
# <td> </td>
#
# </tr>
#
# <tr>
# <td> </td>
#
# <td>? 2 3</td>
#
# </tr>
#
# <tr>
# <td>9</td>
#
# <td> </td>
#
# </tr>
#
# <tr>
# <td> </td>
#
# <td>? 1 5</td>
#
# </tr>
#
# <tr>
# <td>8</td>
#
# <td> </td>
#
# </tr>
#
# <tr>
# <td> </td>
#
# <td>! 14</td>
#
# </tr>
#
# </tbody>
#
# </table>
#
# <p>これは入出力の一つの例であり、意味のある質問をしているとは限らない。</p>
#
# </section>
# </div>
# </div>
#
# </div>
#
#
#
#
# </div>
# </div>
#
#
#
# <hr>
