# %% [markdown]
# <span class='h2'>D - AtCoder社の冬</span>
# <hr>
# <p>Time Limit: 2 sec / Memory Limit: 64 MB</p>
#
# <div id='task-statement'>
# <div class='part'>
# <h3>問題文</h3>
# <section>
# AtCoder社の社員室は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-2'>R</span><span class='MJXp-mo' id='MJXp-Span-3' style='margin-left: 0.267em; margin-right: 0.267em;'>×</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-4'>C</span></span></span><script type='math/tex' id='MathJax-Element-1'>R \times C</script></var>（<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-6'>R</span></span></span><script type='math/tex' id='MathJax-Element-2'>R</script></var> 行 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-7'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-8'>C</span></span></span><script type='math/tex' id='MathJax-Element-3'>C</script></var> 列）の区画に区切られており、各区画には、社員のデスク、サーバーラックのどちらかがあるか、何もない空きスペースのどれかです。<br>
# AtCoder社のある地域の冬は寒く、暖房代をできるだけ節約するため、社員室の必要なスペースのみを区切って使用することに決めました。<br>
# しかし、資材の問題で、区画に平行な長方形の領域で区切らなければいけません。<br>
# そこで、<br>
# <ul>
# <li>デスク、または、サーバーラックのある最も上の行のすぐ上、</li>
# <li>デスク、または、サーバーラックのある最も下の行のすぐ下、</li>
# <li>デスク、または、サーバーラックのある最も左の列のすぐ左、</li>
# <li>デスク、または、サーバーラックのある最も右の列のすぐ右</li>
# </ul>
# の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-9'><span class='MJXp-mn' id='MJXp-Span-10'>4</span></span></span><script type='math/tex' id='MathJax-Element-4'>4</script></var> 辺で囲まれた区画を壁で囲みました。<br>
# すると壁で囲まれた領域は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-11'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-12'>X</span><span class='MJXp-mo' id='MJXp-Span-13' style='margin-left: 0.267em; margin-right: 0.267em;'>×</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-14'>Y</span></span></span><script type='math/tex' id='MathJax-Element-5'>X \times Y</script></var>（<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-15'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-16'>X</span></span></span><script type='math/tex' id='MathJax-Element-6'>X</script></var> 行 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-17'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-18'>Y</span></span></span><script type='math/tex' id='MathJax-Element-7'>Y</script></var> 列）の区画になりました。<br>
# また、AtCoder社の社員室には、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-19'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-20'>D</span></span></span><script type='math/tex' id='MathJax-Element-8'>D</script></var> 個のデスクと、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-21'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-22'>L</span></span></span><script type='math/tex' id='MathJax-Element-9'>L</script></var> 個のサーバーラックがあります。<br>
# もともと、社員室に、どのようにデスクとサーバーラックの配置されていたのか、考えうるパターン数を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-23'><span class='MJXp-mn' id='MJXp-Span-24'>1000000007</span><span class='MJXp-mo' id='MJXp-Span-25' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-msubsup' id='MJXp-Span-26'><span class='MJXp-mn' id='MJXp-Span-27' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-28' style='vertical-align: 0.5em;'>9</span></span><span class='MJXp-mo' id='MJXp-Span-29' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-30'>7</span></span></span><script type='math/tex' id='MathJax-Element-10'>1000000007 = 10^9+7</script></var> で割った余りを求めるプログラムを書いてください。<br>
# </section>
# </div>
#
# <hr>
#
# <div class='io-style part'>
# <h3>入力</h3>
# <section>
# 入力は以下の形式で標準入力から与えられる。
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-31'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-32'>R</span></span></span><script type='math/tex' id='MathJax-Element-11'>R</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-33'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-34'>C</span></span></span><script type='math/tex' id='MathJax-Element-12'>C</script></var>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-35'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-36'>X</span></span></span><script type='math/tex' id='MathJax-Element-13'>X</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-37'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-38'>Y</span></span></span><script type='math/tex' id='MathJax-Element-14'>Y</script></var>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-39'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-40'>D</span></span></span><script type='math/tex' id='MathJax-Element-15'>D</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-41'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-42'>L</span></span></span><script type='math/tex' id='MathJax-Element-16'>L</script></var>
# </pre>
# <ol>
#   <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-43'><span class='MJXp-mn' id='MJXp-Span-44'>1</span></span></span><script type='math/tex' id='MathJax-Element-17'>1</script></var> 行目には、AtCoder社の社員室の区画の行数、列数を表す整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-45'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-46'>R</span><span class='MJXp-mo' id='MJXp-Span-47' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-48'>&nbsp;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-49'>C</span><span class='MJXp-mtext' id='MJXp-Span-50'>&nbsp;</span><span class='MJXp-mo' id='MJXp-Span-51' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-52'>1</span><span class='MJXp-mo' id='MJXp-Span-53' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-54'>R</span><span class='MJXp-mo' id='MJXp-Span-55' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-56'>C</span><span class='MJXp-mo' id='MJXp-Span-57' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mn' id='MJXp-Span-58'>30</span><span class='MJXp-mo' id='MJXp-Span-59' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-18'>R,\ C\ (1 ≦ R, C ≦ 30)</script></var> がスペース区切りで与えられる。</li>
#   <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-60'><span class='MJXp-mn' id='MJXp-Span-61'>2</span></span></span><script type='math/tex' id='MathJax-Element-19'>2</script></var> 行目には、社員室の壁に囲まれた部分の区画の行数、列数を表す整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-62'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-63'>X</span><span class='MJXp-mo' id='MJXp-Span-64' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-65'>&nbsp;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-66'>Y</span><span class='MJXp-mtext' id='MJXp-Span-67'>&nbsp;</span><span class='MJXp-mo' id='MJXp-Span-68' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-69'>1</span><span class='MJXp-mo' id='MJXp-Span-70' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-71'>X</span><span class='MJXp-mo' id='MJXp-Span-72' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-73'>R</span><span class='MJXp-mo' id='MJXp-Span-74' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-75'>&nbsp;</span><span class='MJXp-mn' id='MJXp-Span-76'>1</span><span class='MJXp-mo' id='MJXp-Span-77' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-78'>Y</span><span class='MJXp-mo' id='MJXp-Span-79' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-80'>C</span><span class='MJXp-mo' id='MJXp-Span-81' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-20'>X,\ Y\ (1 ≦ X ≦ R,\ 1 ≦ Y ≦ C)</script></var> がスペース区切りで与えられる。</li>
#   <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-82'><span class='MJXp-mn' id='MJXp-Span-83'>3</span></span></span><script type='math/tex' id='MathJax-Element-21'>3</script></var> 行目には、社員室にある社員のデスクの数、サーバーラックの数を表す整数 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-84'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-85'>D</span><span class='MJXp-mo' id='MJXp-Span-86' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-87'>&nbsp;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-88'>L</span><span class='MJXp-mtext' id='MJXp-Span-89'>&nbsp;</span><span class='MJXp-mo' id='MJXp-Span-90' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-91'>D</span><span class='MJXp-mo' id='MJXp-Span-92' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-93'>L</span><span class='MJXp-mo' id='MJXp-Span-94' style='margin-left: 0.333em; margin-right: 0.333em;'>≧</span><span class='MJXp-mn' id='MJXp-Span-95'>0</span><span class='MJXp-mo' id='MJXp-Span-96' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-97'>&nbsp;</span><span class='MJXp-mn' id='MJXp-Span-98'>1</span><span class='MJXp-mo' id='MJXp-Span-99' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-100'>D</span><span class='MJXp-mo' id='MJXp-Span-101' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-102'>L</span><span class='MJXp-mo' id='MJXp-Span-103' style='margin-left: 0.333em; margin-right: 0.333em;'>≦</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-104'>X</span><span class='MJXp-mo' id='MJXp-Span-105' style='margin-left: 0.267em; margin-right: 0.267em;'>×</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-106'>Y</span><span class='MJXp-mo' id='MJXp-Span-107' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-22'>D,\ L\ (D, L ≧ 0,\ 1 ≦ D+L ≦ X \times Y)</script></var> がスペース区切りで与えられる。</li>
# </ol>
# </section>
# </div>
#
# <div class='part'>
# <h3>出力</h3>
# <section>
# 社員室にどのようにデスクとサーバーラックの配置されていたのか、考えうるパターン数を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-108'><span class='MJXp-mn' id='MJXp-Span-109'>1000000007</span><span class='MJXp-mo' id='MJXp-Span-110' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-msubsup' id='MJXp-Span-111'><span class='MJXp-mn' id='MJXp-Span-112' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-113' style='vertical-align: 0.5em;'>9</span></span><span class='MJXp-mo' id='MJXp-Span-114' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-115'>7</span></span></span><script type='math/tex' id='MathJax-Element-23'>1000000007 = 10^9+7</script></var> で割った余りを <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-116'><span class='MJXp-mn' id='MJXp-Span-117'>1</span></span></span><script type='math/tex' id='MathJax-Element-24'>1</script></var> 行で出力せよ。<br>
# また、出力の末尾には改行を入れること。
# </section>
# </div>
#
# <div class='part'>
# <h3>部分点</h3>
# <section>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-118'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-119'>D</span><span class='MJXp-mo' id='MJXp-Span-120' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-121'>L</span><span class='MJXp-mo' id='MJXp-Span-122' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-123'>X</span><span class='MJXp-mo' id='MJXp-Span-124' style='margin-left: 0.267em; margin-right: 0.267em;'>×</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-125'>Y</span></span></span><script type='math/tex' id='MathJax-Element-25'>D+L = X \times Y</script></var> の場合のテストケースに全て正解した場合、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-126'><span class='MJXp-mn' id='MJXp-Span-127'>101</span></span></span><script type='math/tex' id='MathJax-Element-26'>101</script></var> 点満点中の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-128'><span class='MJXp-mn' id='MJXp-Span-129'>100</span></span></span><script type='math/tex' id='MathJax-Element-27'>100</script></var> 点が与えられる。<br>
# 満点解法は非常に難しいので、部分点を確実に取ることから考えましょう。
# </section>
# </div>
#
# <hr>
#
# <div class='part'>
# <h3>入力例 1</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy0' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>3</span><span class='pln'> </span><span class='lit'>2</span></li><li class='L1'><span class='lit'>2</span><span class='pln'> </span><span class='lit'>2</span></li><li class='L2'><span class='lit'>2</span><span class='pln'> </span><span class='lit'>2</span></li></ol></pre><pre id='for_copy0' class='source-code-for-copy'>3 2
# 2 2
# 2 2
# </pre>
# </section>
#
# </div>
#
# <div class='part'>
# <h3>出力例 1</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy1' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>12</span></li></ol></pre><pre id='for_copy1' class='source-code-for-copy'>12
# </pre>
# <ul>
#   <li>このケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-130'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-131'>D</span><span class='MJXp-mo' id='MJXp-Span-132' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-133'>L</span><span class='MJXp-mo' id='MJXp-Span-134' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-135'>X</span><span class='MJXp-mo' id='MJXp-Span-136' style='margin-left: 0.267em; margin-right: 0.267em;'>×</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-137'>Y</span></span></span><script type='math/tex' id='MathJax-Element-28'>D+L=X \times Y</script></var> を満たすため、部分点のテストケースに含まれる可能性があります。</li>
#   <li>以下の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-138'><span class='MJXp-mn' id='MJXp-Span-139'>12</span></span></span><script type='math/tex' id='MathJax-Element-29'>12</script></var> 通りの配置が考えられます。ここで<code>D</code>はデスク、<code>L</code>はサーバーラック、<code>.</code>は何もないことを表します。</li>
# </ul>
# <pre>DD  DL  DL  LD  LD  LL  ..  ..  ..  ..  ..  ..
# LL  DL  LD  DL  LD  DD  DD  DL  DL  LD  LD  LL
# ..  ..  ..  ..  ..  ..  LL  DL  LD  DL  LD  DD
# </pre>
# </section>
# </div>
#
# <hr>
#
# <div class='part'>
# <h3>入力例 2</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy2' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>4</span><span class='pln'> </span><span class='lit'>5</span></li><li class='L1'><span class='lit'>3</span><span class='pln'> </span><span class='lit'>1</span></li><li class='L2'><span class='lit'>3</span><span class='pln'> </span><span class='lit'>0</span></li></ol></pre><pre id='for_copy2' class='source-code-for-copy'>4 5
# 3 1
# 3 0
# </pre>
# </section>
# </div>
#
# <div class='part'>
# <h3>出力例 2</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy3' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>10</span></li></ol></pre><pre id='for_copy3' class='source-code-for-copy'>10
# </pre>
# <ul>
#   <li>このケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-140'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-141'>D</span><span class='MJXp-mo' id='MJXp-Span-142' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-143'>L</span><span class='MJXp-mo' id='MJXp-Span-144' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-145'>X</span><span class='MJXp-mo' id='MJXp-Span-146' style='margin-left: 0.267em; margin-right: 0.267em;'>×</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-147'>Y</span></span></span><script type='math/tex' id='MathJax-Element-30'>D+L=X \times Y</script></var> を満たすため、部分点のテストケースに含まれる可能性があります。</li>
# </ul>
# </section>
# </div>
#
# <hr>
#
# <div class='part'>
# <h3>入力例 3</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy4' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>23</span><span class='pln'> </span><span class='lit'>18</span></li><li class='L1'><span class='lit'>15</span><span class='pln'> </span><span class='lit'>13</span></li><li class='L2'><span class='lit'>100</span><span class='pln'> </span><span class='lit'>95</span></li></ol></pre><pre id='for_copy4' class='source-code-for-copy'>23 18
# 15 13
# 100 95
# </pre>
# </section>
# </div>
#
# <div class='part'>
# <h3>出力例 3</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy5' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>364527243</span></li></ol></pre><pre id='for_copy5' class='source-code-for-copy'>364527243
# </pre>
# <ul>
#   <li>このケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-148'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-149'>D</span><span class='MJXp-mo' id='MJXp-Span-150' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-151'>L</span><span class='MJXp-mo' id='MJXp-Span-152' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-153'>X</span><span class='MJXp-mo' id='MJXp-Span-154' style='margin-left: 0.267em; margin-right: 0.267em;'>×</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-155'>Y</span></span></span><script type='math/tex' id='MathJax-Element-31'>D+L=X \times Y</script></var> を満たすため、部分点のテストケースに含まれる可能性があります。</li>
#   <li>社員室の配置パターンは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-156'><span class='MJXp-mn' id='MJXp-Span-157'>145180660592914517790287604376765671109248284280228061640640</span></span></span><script type='math/tex' id='MathJax-Element-32'>145180660592914517790287604376765671109248284280228061640640</script></var> 通りで、これを <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-158'><span class='MJXp-msubsup' id='MJXp-Span-159'><span class='MJXp-mn' id='MJXp-Span-160' style='margin-right: 0.05em;'>10</span><span class='MJXp-mn MJXp-script' id='MJXp-Span-161' style='vertical-align: 0.5em;'>9</span></span><span class='MJXp-mo' id='MJXp-Span-162' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mn' id='MJXp-Span-163'>7</span></span></span><script type='math/tex' id='MathJax-Element-33'>10^9+7</script></var> で割った余りである <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-164'><span class='MJXp-mn' id='MJXp-Span-165'>364527243</span></span></span><script type='math/tex' id='MathJax-Element-34'>364527243</script></var> を出力してください。</li>
# </ul>
# </section>
# </div>
#
# <div class='part'>
# <h3>入力例 4</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy6' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>30</span><span class='pln'> </span><span class='lit'>30</span></li><li class='L1'><span class='lit'>24</span><span class='pln'> </span><span class='lit'>22</span></li><li class='L2'><span class='lit'>145</span><span class='pln'> </span><span class='lit'>132</span></li></ol></pre><pre id='for_copy6' class='source-code-for-copy'>30 30
# 24 22
# 145 132
# </pre>
# </section>
# </div>
#
# <div class='part'>
# <h3>出力例 4</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy7' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>976668549</span></li></ol></pre><pre id='for_copy7' class='source-code-for-copy'>976668549
# </pre>
# <ul>
#   <li>このケースは <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-166'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-167'>D</span><span class='MJXp-mo' id='MJXp-Span-168' style='margin-left: 0.267em; margin-right: 0.267em;'>+</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-169'>L</span><span class='MJXp-mo' id='MJXp-Span-170' style='margin-left: 0.333em; margin-right: 0.333em;'>=</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-171'>X</span><span class='MJXp-mo' id='MJXp-Span-172' style='margin-left: 0.267em; margin-right: 0.267em;'>×</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-173'>Y</span></span></span><script type='math/tex' id='MathJax-Element-35'>D+L=X \times Y</script></var> を満たさないため、部分点のテストケースに含まれることはありません。</li>
#   <li>無理に正解しようとせず、余裕のある人だけ挑戦してみてください。</li>
# </ul>
# </section>
# </div>
# </div>
#
#
#
#
# </div>
# </div>
#
#
#
# <hr>
