# %% [markdown]
# <span class='h2'>C - 直訴</span>
# <hr>
# <p>Time Limit: 2 sec / Memory Limit: 64 MB</p>
#
# <div id='task-statement'>
# <div class='part'>
# <h3>問題文</h3>
# <section>
# 神に盗まれた母音を取り戻すため、高橋くんは神へ直訴しました。<br>
# 「神様、どうかお願いです。僕の母音を返してください。」<br>
# 神はこう言いました。<br>
# 「そんなに母音がほしいのか。ならば私の仕事を手伝ってもらおう。」<br>
# <br>
# 現在、神は天界のいたるところで測量を行っており、高橋くんは神の測量を手伝わなければなりません。<br>
# 今回は三角形の測量です。高橋くんには <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-1'><span class='MJXp-mn' id='MJXp-Span-2'>2</span></span></span><script type='math/tex' id='MathJax-Element-1'>2</script></var> 次元平面上の <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-3'><span class='MJXp-mn' id='MJXp-Span-4'>3</span></span></span><script type='math/tex' id='MathJax-Element-2'>3</script></var> つの点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-5'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-6'>A</span><span class='MJXp-mo' id='MJXp-Span-7' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-8'>&nbsp;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-9'>B</span><span class='MJXp-mo' id='MJXp-Span-10' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-11'>&nbsp;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-12'>C</span></span></span><script type='math/tex' id='MathJax-Element-3'>A,\ B,\ C</script></var> が与えられます。<br>
# 少しでも早く母音を取り戻すために、三角形 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-13'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-14'>A</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-15'>B</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-16'>C</span></span></span><script type='math/tex' id='MathJax-Element-4'>ABC</script></var> の面積を出力するプログラムを書いてください。
# </section>
# </div>
#
# <hr>
#
# <div class='io-style part'>
# <h3>入力</h3>
# <section>
# 入力は以下の形式で標準入力から与えられる。
# <pre><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-17'><span class='MJXp-msubsup' id='MJXp-Span-18'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-19' style='margin-right: 0.05em;'>x</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-20' style='vertical-align: -0.4em;'>a</span></span></span></span><script type='math/tex' id='MathJax-Element-5'>x_a</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-21'><span class='MJXp-msubsup' id='MJXp-Span-22'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-23' style='margin-right: 0.05em;'>y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-24' style='vertical-align: -0.4em;'>a</span></span></span></span><script type='math/tex' id='MathJax-Element-6'>y_a</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-25'><span class='MJXp-msubsup' id='MJXp-Span-26'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-27' style='margin-right: 0.05em;'>x</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-28' style='vertical-align: -0.4em;'>b</span></span></span></span><script type='math/tex' id='MathJax-Element-7'>x_b</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-29'><span class='MJXp-msubsup' id='MJXp-Span-30'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-31' style='margin-right: 0.05em;'>y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-32' style='vertical-align: -0.4em;'>b</span></span></span></span><script type='math/tex' id='MathJax-Element-8'>y_b</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-33'><span class='MJXp-msubsup' id='MJXp-Span-34'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-35' style='margin-right: 0.05em;'>x</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-36' style='vertical-align: -0.4em;'>c</span></span></span></span><script type='math/tex' id='MathJax-Element-9'>x_c</script></var> <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-37'><span class='MJXp-msubsup' id='MJXp-Span-38'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-39' style='margin-right: 0.05em;'>y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-40' style='vertical-align: -0.4em;'>c</span></span></span></span><script type='math/tex' id='MathJax-Element-10'>y_c</script></var>
# </pre>
# <ol>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-41'><span class='MJXp-mn' id='MJXp-Span-42'>1</span></span></span><script type='math/tex' id='MathJax-Element-11'>1</script></var> 行目には、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-43'><span class='MJXp-mn' id='MJXp-Span-44'>3</span></span></span><script type='math/tex' id='MathJax-Element-12'>3</script></var> 点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-45'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-46'>A</span><span class='MJXp-mo' id='MJXp-Span-47' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-48'>&nbsp;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-49'>B</span><span class='MJXp-mo' id='MJXp-Span-50' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-51'>&nbsp;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-52'>C</span></span></span><script type='math/tex' id='MathJax-Element-13'>A,\ B,\ C</script></var> の座標が半角空白区切りで与えられる。</li>
# <ul>
# <li>点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-53'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-54'>A</span></span></span><script type='math/tex' id='MathJax-Element-14'>A</script></var> の座標が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-55'><span class='MJXp-mo' id='MJXp-Span-56' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-msubsup' id='MJXp-Span-57'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-58' style='margin-right: 0.05em;'>x</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-59' style='vertical-align: -0.4em;'>a</span></span><span class='MJXp-mo' id='MJXp-Span-60' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-61'>&nbsp;</span><span class='MJXp-msubsup' id='MJXp-Span-62'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-63' style='margin-right: 0.05em;'>y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-64' style='vertical-align: -0.4em;'>a</span></span><span class='MJXp-mo' id='MJXp-Span-65' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-15'>(x_a,\ y_a)</script></var>、点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-66'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-67'>B</span></span></span><script type='math/tex' id='MathJax-Element-16'>B</script></var> の座標が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-68'><span class='MJXp-mo' id='MJXp-Span-69' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-msubsup' id='MJXp-Span-70'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-71' style='margin-right: 0.05em;'>x</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-72' style='vertical-align: -0.4em;'>b</span></span><span class='MJXp-mo' id='MJXp-Span-73' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-74'>&nbsp;</span><span class='MJXp-msubsup' id='MJXp-Span-75'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-76' style='margin-right: 0.05em;'>y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-77' style='vertical-align: -0.4em;'>b</span></span><span class='MJXp-mo' id='MJXp-Span-78' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-17'>(x_b,\ y_b)</script></var>、点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-79'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-80'>C</span></span></span><script type='math/tex' id='MathJax-Element-18'>C</script></var> の座標が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-81'><span class='MJXp-mo' id='MJXp-Span-82' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-msubsup' id='MJXp-Span-83'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-84' style='margin-right: 0.05em;'>x</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-85' style='vertical-align: -0.4em;'>c</span></span><span class='MJXp-mo' id='MJXp-Span-86' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-87'>&nbsp;</span><span class='MJXp-msubsup' id='MJXp-Span-88'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-89' style='margin-right: 0.05em;'>y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-90' style='vertical-align: -0.4em;'>c</span></span><span class='MJXp-mo' id='MJXp-Span-91' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-19'>(x_c,\ y_c)</script></var> であることを表す。</li>
# <li>各座標の値 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-92'><span class='MJXp-msubsup' id='MJXp-Span-93'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-94' style='margin-right: 0.05em;'>x</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-95' style='vertical-align: -0.4em;'>a</span></span><span class='MJXp-mo' id='MJXp-Span-96' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-97'>&nbsp;</span><span class='MJXp-msubsup' id='MJXp-Span-98'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-99' style='margin-right: 0.05em;'>y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-100' style='vertical-align: -0.4em;'>a</span></span><span class='MJXp-mo' id='MJXp-Span-101' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-102'>&nbsp;</span><span class='MJXp-msubsup' id='MJXp-Span-103'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-104' style='margin-right: 0.05em;'>x</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-105' style='vertical-align: -0.4em;'>b</span></span><span class='MJXp-mo' id='MJXp-Span-106' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-107'>&nbsp;</span><span class='MJXp-msubsup' id='MJXp-Span-108'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-109' style='margin-right: 0.05em;'>y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-110' style='vertical-align: -0.4em;'>b</span></span><span class='MJXp-mo' id='MJXp-Span-111' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-112'>&nbsp;</span><span class='MJXp-msubsup' id='MJXp-Span-113'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-114' style='margin-right: 0.05em;'>x</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-115' style='vertical-align: -0.4em;'>c</span></span><span class='MJXp-mo' id='MJXp-Span-116' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-117'>&nbsp;</span><span class='MJXp-msubsup' id='MJXp-Span-118'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-119' style='margin-right: 0.05em;'>y</span><span class='MJXp-mi MJXp-italic MJXp-script' id='MJXp-Span-120' style='vertical-align: -0.4em;'>c</span></span></span></span><script type='math/tex' id='MathJax-Element-20'>x_a,\ y_a,\ x_b,\ y_b,\ x_c,\ y_c</script></var> は <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-121'><span class='MJXp-mo' id='MJXp-Span-122' style='margin-left: 0em; margin-right: 0.111em;'>−</span><span class='MJXp-mn' id='MJXp-Span-123'>1</span><span class='MJXp-mo' id='MJXp-Span-124' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-125'>000</span></span></span><script type='math/tex' id='MathJax-Element-21'>-1,000</script></var> 以上 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-126'><span class='MJXp-mn' id='MJXp-Span-127'>1</span><span class='MJXp-mo' id='MJXp-Span-128' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-129'>000</span></span></span><script type='math/tex' id='MathJax-Element-22'>1,000</script></var> 以下の整数であることが保証されている。</li>
# <li><var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-130'><span class='MJXp-mn' id='MJXp-Span-131'>3</span></span></span><script type='math/tex' id='MathJax-Element-23'>3</script></var> 点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-132'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-133'>A</span><span class='MJXp-mo' id='MJXp-Span-134' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-135'>&nbsp;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-136'>B</span><span class='MJXp-mo' id='MJXp-Span-137' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-138'>&nbsp;</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-139'>C</span></span></span><script type='math/tex' id='MathJax-Element-24'>A,\ B,\ C</script></var> が同一直線上に配置されていることはない。</li>
# </ul>
# </ol>
# </section>
# </div>
#
# <div class='iopart part'>
# <h3>出力</h3>
# <section>
# 三角形 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-140'><span class='MJXp-mi MJXp-italic' id='MJXp-Span-141'>A</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-142'>B</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-143'>C</span></span></span><script type='math/tex' id='MathJax-Element-25'>ABC</script></var> の面積を <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-144'><span class='MJXp-mn' id='MJXp-Span-145'>1</span></span></span><script type='math/tex' id='MathJax-Element-26'>1</script></var> 行で出力してください。<br>
# また、出力の末尾には改行を入れること。<br>
# 出力は絶対誤差が <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-146'><span class='MJXp-msubsup' id='MJXp-Span-147'><span class='MJXp-mn' id='MJXp-Span-148' style='margin-right: 0.05em;'>10</span><span class='MJXp-mrow MJXp-script' id='MJXp-Span-149' style='vertical-align: 0.5em;'><span class='MJXp-mo' id='MJXp-Span-150'>−</span><span class='MJXp-mn' id='MJXp-Span-151'>2</span></span></span></span></span><script type='math/tex' id='MathJax-Element-27'>10^{-2}</script></var> 以下であれば許容される。
# </section>
# </div>
#
# <hr>
#
# <div class='iopart part'>
# <h3>ヒント</h3>
# <section>
# <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-152'><span class='MJXp-mn' id='MJXp-Span-153'>3</span></span></span><script type='math/tex' id='MathJax-Element-28'>3</script></var> 点 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-154'><span class='MJXp-mo' id='MJXp-Span-155' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mn' id='MJXp-Span-156'>0</span><span class='MJXp-mo' id='MJXp-Span-157' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mn' id='MJXp-Span-158'>0</span><span class='MJXp-mo' id='MJXp-Span-159' style='margin-left: 0em; margin-right: 0em;'>)</span><span class='MJXp-mo' id='MJXp-Span-160' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-161'>&nbsp;</span><span class='MJXp-mo' id='MJXp-Span-162' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-163'>a</span><span class='MJXp-mo' id='MJXp-Span-164' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-165'>b</span><span class='MJXp-mo' id='MJXp-Span-166' style='margin-left: 0em; margin-right: 0em;'>)</span><span class='MJXp-mo' id='MJXp-Span-167' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mtext' id='MJXp-Span-168'>&nbsp;</span><span class='MJXp-mo' id='MJXp-Span-169' style='margin-left: 0em; margin-right: 0em;'>(</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-170'>c</span><span class='MJXp-mo' id='MJXp-Span-171' style='margin-left: 0em; margin-right: 0.222em;'>,</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-172'>d</span><span class='MJXp-mo' id='MJXp-Span-173' style='margin-left: 0em; margin-right: 0em;'>)</span></span></span><script type='math/tex' id='MathJax-Element-29'>(0,0),\ (a,b),\ (c,d)</script></var> で構成される三角形の面積は、<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-174'><span class='MJXp-mrow' id='MJXp-Span-175'><span class='MJXp-mo' id='MJXp-Span-176' style='margin-left: 0.167em; margin-right: 0.167em;'>|</span></span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-177'>a</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-178'>d</span><span class='MJXp-mo' id='MJXp-Span-179' style='margin-left: 0.267em; margin-right: 0.267em;'>−</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-180'>b</span><span class='MJXp-mi MJXp-italic' id='MJXp-Span-181'>c</span><span class='MJXp-mrow' id='MJXp-Span-182'><span class='MJXp-mo' id='MJXp-Span-183' style='margin-left: 0.167em; margin-right: 0.167em;'>|</span></span><span class='MJXp-mrow' id='MJXp-Span-184'><span class='MJXp-mo' id='MJXp-Span-185' style='margin-left: 0.111em; margin-right: 0.111em;'>/</span></span><span class='MJXp-mn' id='MJXp-Span-186'>2</span></span></span><script type='math/tex' id='MathJax-Element-30'>|ad-bc|/2</script></var> となります。<br>
# （このヒントは、コンテスト開始 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-187'><span class='MJXp-mn' id='MJXp-Span-188'>1</span></span></span><script type='math/tex' id='MathJax-Element-31'>1</script></var> 時間後に公開されたものです。）
# </section>
# </div>
#
# <hr>
#
# <div class='part'>
# <h3>入力例 1</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy0' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>1</span><span class='pln'> </span><span class='lit'>0</span><span class='pln'> </span><span class='lit'>3</span><span class='pln'> </span><span class='lit'>0</span><span class='pln'> </span><span class='lit'>2</span><span class='pln'> </span><span class='lit'>5</span></li></ol></pre><pre id='for_copy0' class='source-code-for-copy'>1 0 3 0 2 5
# </pre>
# </section>
# </div>
#
# <div class='part'>
# <h3>出力例 1</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy1' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>5.0</span></li></ol></pre><pre id='for_copy1' class='source-code-for-copy'>5.0
# </pre>
# <ul>
# <div class='img-caption'>
# <img src='/img/abc/002/3_1.png' width='360' height='280'>
# <div class='caption'>図<var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-189'><span class='MJXp-mn' id='MJXp-Span-190'>1</span></span></span><script type='math/tex' id='MathJax-Element-32'>1</script></var>：入力例 <var><span class='MathJax_Preview' style='color: inherit;'><span class='MJXp-math' id='MJXp-Span-191'><span class='MJXp-mn' id='MJXp-Span-192'>1</span></span></span><script type='math/tex' id='MathJax-Element-33'>1</script></var> を図示したもの</div>
# </div>
# </ul>
# </section>
# </div>
#
# <hr>
#
# <div class='part'>
# <h3>入力例 2</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy2' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='pun'>-</span><span class='lit'>1</span><span class='pln'> </span><span class='pun'>-</span><span class='lit'>2</span><span class='pln'> </span><span class='lit'>3</span><span class='pln'> </span><span class='lit'>4</span><span class='pln'> </span><span class='lit'>5</span><span class='pln'> </span><span class='lit'>6</span></li></ol></pre><pre id='for_copy2' class='source-code-for-copy'>-1 -2 3 4 5 6
# </pre>
# </section>
# </div>
#
# <div class='part'>
# <h3>出力例 2</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy3' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>2.0</span></li></ol></pre><pre id='for_copy3' class='source-code-for-copy'>2.0
# </pre>
# </section>
# </div>
#
#
# <hr>
#
# <div class='part'>
# <h3>入力例 3</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy4' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>298</span><span class='pln'> </span><span class='lit'>520</span><span class='pln'> </span><span class='lit'>903</span><span class='pln'> </span><span class='lit'>520</span><span class='pln'> </span><span class='lit'>4</span><span class='pln'> </span><span class='lit'>663</span></li></ol></pre><pre id='for_copy4' class='source-code-for-copy'>298 520 903 520 4 663
# </pre>
# </section>
# </div>
#
# <div class='part'>
# <h3>出力例 3</h3>
# <section>
# <div class='div-btn-copy'><span class='btn-copy btn-pre' tabindex='0' data-toggle='tooltip' data-trigger='manual' title='' style='display: none;' data-target='for_copy5' data-original-title='Copied!'>Copy</span></div><pre class='prettyprint linenums source-code prettyprinted' style='display: none;'><ol class='linenums'><li class='L0'><span class='lit'>43257.5</span></li></ol></pre><pre id='for_copy5' class='source-code-for-copy'>43257.5
# </pre>
# </section>
# </div>
# </div>
#
#
#
#
# </div>
# </div>
#
#
#
# <hr>

# %%
from ipywidgets import Textarea
import sys
sys.path.append('../../..')

from utils.multi_line_input import multi_line_input
text_area = Textarea()
input = multi_line_input()

display(text_area)
